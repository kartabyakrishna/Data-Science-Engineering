# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import string
from string import digits
import re
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Input, Dense,Embedding, Concatenate, TimeDistributed
from tensorflow.keras.models import Model,load_model, model_from_json
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
import tensorflow as tf
import pickle as pkl
import numpy as np

# %%
with open('kan.txt','r') as f:
    data = f.readlines()

# %%
data
# Out:
# ["What's up?\tಆರಾಮಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #25164 (CK) & #8902986 (satez416)\n",
#  'How are you?\tಹೇಗಿದ್ದೀರ\tCC-BY 2.0 (France) Attribution: tatoeba.org #373320 (CK) & #8902982 (satez416)\n',
#  'Tom woke up.\tಟಾಮ್ ಏಳಿದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2240217 (CK) & #4776457 (legalghost)\n',
#  'Give me half.\tಅರ್ಧ ನನಗೆ ಕೊಡು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2043700 (CK) & #4776542 (legalghost)\n',
#  'We needed it.\tನಮಗೆ ಬೇಕಾಗಿತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4501171 (CK) & #4784813 (legalghost)\n',
#  "I'm very busy.\tನಾನು ತುಂಬಾ ಬಿಝಿ\tCC-BY 2.0 (France) Attribution: tatoeba.org #433991 (CK) & #8902992 (satez416)\n",
#  'Tom liked you.\tಟಾಮ್ ನಿನ್ನನ್ನು ಬಯಸಿದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2237161 (CK) & #4776861 (legalghost)\n',
#  'Just go inside.\tಒಳಗೆ ಹೋಗು ಅಷ್ಟೇ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2249423 (CK) & #4774747 (legalghost)\n',
#  'Do you remember?\tನಿಮಗೆ ನೆನಪು ಇದ್ಯಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #21678 (CK) & #4784802 (legalghost)\n',
#  'I just got back.\tನಾನು ಈಗ ತಾನೇ ವಾಪಸ್ಸು ಬಂದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2362200 (CK) & #4775547 (legalghost)\n',
#  'See you at 2:30.\tಎರಡು ವರೆಗೆ (೨.೩೦ ಗೆ) ನಿನ್ನನ್ನು ನೋಡುತ್ತೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2648982 (CK) & #4775449 (legalghost)\n',
#  'Can we go inside?\tನಾವು ಒಳಗಡೆ ಹೋಗಬಹುದಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2835777 (CK) & #4774653 (legalghost)\n',
#  'I believe in you.\tನಾನು ನಿನ್ನ ಮೇಲೆ ನಂಬಿಕೆ ಇಟ್ಟಿದ್ದೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #237698 (CK) & #4784822 (legalghost)\n',
#  'Mary is gorgeous.\tಮೇರಿ ಸೌಂದರ್ಯವಾಗಿದ್ದಾಳೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2202905 (CK) & #4784794 (legalghost)\n',
#  "How's your family?\tನಿಮ್ಮ ಮನೇಲಿ ಹೆಂಗಿದ್ದಾರೆ\tCC-BY 2.0 (France) Attribution: tatoeba.org #54503 (CK) & #8902990 (satez416)\n",
#  'Where is the book?\tಪುಸ್ತಕ ಎಲ್ಲಿದೆ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #43928 (CK) & #4776859 (legalghost)\n',
#  'Tom stayed with me.\tಟಾಮ್ ನನ್ನ ಜೊತೆ ಉಳಿದುಕೊಂಡನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3184901 (CK) & #4774742 (legalghost)\n',
#  "Don't let Tom do it.\tಟೊಮನ್ನು ಅದನ್ನು ಮಾಡಕ್ಕೆ ಬಿಡಬೇಡಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2275257 (CK) & #4774624 (legalghost)\n",
#  'May I put this here?\tನಾನು ಅದನ್ನು ಇಲ್ಲಿ ಇಡಬಹುದೇ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #6890519 (CK) & #11791434 (akshayvnayak)\n',
#  "They're useless now.\tಅವರು ಏನಕ್ಕೂ ಉಪಯೋಗವಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2243698 (CK) & #4774749 (legalghost)\n",
#  "We're working on it.\tನಾವು ಅದರ ಕುರಿತು ಕೆಲಸ ಮಾಡುತ್ತಾ ಇದ್ದೇವೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1893605 (CK) & #4775475 (legalghost)\n",
#  'I traveled by myself.\tನಾನು ಒಂಟಿಯಾಗಿ ಪಯಣ ಮಾಡಿದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #255488 (CK) & #4776456 (legalghost)\n',
#  'Tom is very careless.\tಟಾಮ್ ತುಂಬಾನೇ ಅಸಡ್ಡೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3422190 (CK) & #4784812 (legalghost)\n',
#  "What's going on here?\tಇಲ್ಲಿ ಏನು ನಡಿತಾಯಿದೆ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #61911 (CK) & #5387062 (legalghost)\n",
#  'You have to tell Tom.\tನೀವು ಟಾಮಿಗೆ ಹೇಳಲೇಬೇಕು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3170979 (CK) & #4783932 (legalghost)\n',
#  'You let me down, Tom.\tನೀನು ನನ್ನನು ನಿರಾಶೆ ಮಾಡುತ್ತೀಯ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3342770 (CK) & #4776827 (legalghost)\n',
#  'Did Tom ever hurt you?\tಟಾಮ್ ನಿನ್ನನ್ನು ಯಾವಾಗಲಾದರೂ ನೋಯಿಸಿದ್ದಾನಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #3402383 (CK) & #4783943 (legalghost)\n',
#  'I gave Tom a huge hug.\tನಾನು ಟೊಮನ್ನು ಬಿಗಿಯಾಗಿ ತಬ್ಬಿಕೊಂಡೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3330440 (CK) & #4774620 (legalghost)\n',
#  "That's all Tom needed.\tಅದಷ್ಟೇ ಟಾಮಿಗೆ ಬೇಕಾಗಿದ್ದು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2892018 (CK) & #4784804 (legalghost)\n",
#  'I must be getting home.\tನಾನು ಮನೆಗೆ ಹೊರಡುತ್ತಾ ಇರಬೇಕು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3733157 (CK) & #4784820 (legalghost)\n',
#  'I think that went well.\tಚನ್ನಾಗಿ ನಡೆಯಿತು ಅಂತ ಅನಿಸುತ್ತೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2408147 (CK) & #4776864 (legalghost)\n',
#  "Let's greet our guests.\tನಮ್ಮ ಅತಿಥಿಗಳನ್ನು ಸ್ವಾಗತಿಸೋಣ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2007628 (CK) & #4774678 (legalghost)\n",
#  'Stupidity is no excuse.\tಮೂರ್ಖತನಕ್ಕೆ ಯಾವ ಕ್ಷಮೆಯು ಇಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3733501 (CK) & #4776855 (legalghost)\n',
#  'You need to stay awake.\tನೀವು ಎಚ್ಚರವಾಗಿರಬೇಕು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3178325 (CK) & #4784809 (legalghost)\n',
#  'Eat a lot of vegetables.\tಬಹಳ ತರಕಾರಿಗಳು ತಿನ್ನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #324120 (CK) & #4784823 (legalghost)\n',
#  'I had to get some money.\tನಾನು ಸ್ವಲ್ಪ ದುಡ್ಡನ್ನು ತೆಗೆದುಕೊಂಡು ಬರಬೇಕಾಗಿತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2331798 (CK) & #4784785 (legalghost)\n',
#  'I only wish to help you.\tನಿಮ್ಮನ್ನು ಸಹಾಯ ಮಾಡುವುದಕ್ಕೆ ಆಶಿಸುತ್ತೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2389548 (CK) & #4775511 (legalghost)\n',
#  'Why are you thanking me?\tನೀವು ಯಾಕೆ ನನಗೆ ಧನ್ಯವಾದ ಹೇಳುತ್ತೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #3822569 (CK) & #4775458 (legalghost)\n',
#  'He swam across the river.\tಅವನು ನದಿ ಅಡ್ಡಲಾಗಿ ಈಜಿದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #291092 (CK) & #4774755 (legalghost)\n',
#  'How did it go last night?\tನೆನ್ನೆ ರಾತ್ರಿ ಹೇಗೆ ನಡೆಯಿತು?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2030096 (CK) & #4783940 (legalghost)\n',
#  "I've never been to Paris.\tನಾನು ಪ್ಯಾರಿಸಿಗೆ ಎಂದಿಗೂ ಹೋಗಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #32654 (CK) & #4784801 (legalghost)\n",
#  'Tom had almost forgotten.\tಟಾಮ್ ಬಹುಮಟ್ಟಿಗೆ ಮರೆತುಬಿಟ್ಟಿದ್ದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2644923 (CK) & #4776838 (legalghost)\n',
#  'Tom is a real competitor.\tಟಾಮ್ ಒಬ್ಬ ಒಳ್ಳೆಯ ಪ್ರತಿಸ್ಪರ್ಧಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4666359 (CK) & #4784791 (legalghost)\n',
#  'Tom is ready for you now.\tಟಾಮ್ ಈಗ ನಿಮಗೆ ತಯಾರಾಗಿದ್ದಾನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2644890 (CK) & #4776794 (legalghost)\n',
#  'Tom left three hours ago.\tಟಾಮ್ ಮೂರು ಗಂಟೆಯ ಮುಂಚೇನೇ ಹೋದ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3431003 (CK) & #4774652 (legalghost)\n',
#  'Tom told Mary to go home.\tಟಾಮ್ ಮೇರಿಗೆ ಮನೆಗೆ ಹೋಗುವುದಕ್ಕೆ ಹೇಳಿದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1867852 (CK) & #4776862 (legalghost)\n',
#  'You are in love with him.\tನೀನು ಅವನನ್ನು ಪ್ರೀತಿಸುತ್ತಿದ್ದೀಯ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2545062 (CK) & #4774190 (legalghost)\n',
#  'He agrees with my opinion.\tಅವನು ನನ್ನ ಅಭಿಪ್ರಾಯವನ್ನು ಸಮ್ಮತಿಸುತ್ತಾನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #403320 (CK) & #4776808 (legalghost)\n',
#  'He goes abroad every year.\tಪ್ರತಿವರ್ಷ ಅವನು ವಿದೇಶಕ್ಕೆ ಹೋಗುತ್ತಾನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #303926 (CK) & #4776869 (legalghost)\n',
#  'How did you get that scar?\tಆ ಗಾಯ ಹೇಗೆ ಸಿಕ್ಕಿತು?\tCC-BY 2.0 (France) Attribution: tatoeba.org #5379348 (Hybrid) & #5387071 (legalghost)\n',
#  "I've always believed that.\tನಾನು ಎಂದಿಗೂ ಅದನ್ನೇ ನಂಬಿದ್ದೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2358934 (CK) & #4776867 (legalghost)\n",
#  'Last night, I read a book.\tನೆನ್ನೆ ರಾತ್ರಿ ನಾನು ಒಂದು ಪುಸ್ತಕವನ್ನು ಓದಿದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2744171 (CK) & #4784789 (legalghost)\n',
#  'One of us will have to go.\tನಮ್ಮಲ್ಲಿ ಒಬ್ಬರು ಹೋಗಲೇ ಬೇಕಾಗುತ್ತದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #38003 (CK) & #4784782 (legalghost)\n',
#  'The war is still going on.\tಯುದ್ಧ ಇನ್ನೂ ನಡೆಯುತ್ತಿದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #273302 (CK) & #4775502 (legalghost)\n',
#  'The weather is nice today.\tಇವತ್ತು ವೆದರ್ ಚೆನ್ನಾಗಿದೆ\tCC-BY 2.0 (France) Attribution: tatoeba.org #3688260 (tom0483) & #8901603 (satez416)\n',
#  "Tom doesn't eat much meat.\tಟಾಮ್ ಹೆಚ್ಚು ಮಾಂಸ ತಿನ್ನುವುದಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2023748 (CK) & #4775442 (legalghost)\n",
#  'We were caught in a storm.\tನಾವು ಬಿರುಗಾಳಿಯಿಂದ ಸಿಕ್ಕಿಹಾಕಿಕೊಳ್ಳಿದ್ದೆವಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #22638 (CK) & #4775427 (legalghost)\n',
#  'What team do you play for?\tನೀವು ಯಾವ ತಂಡಕ್ಕೆ ಆಟ ಆಡುತ್ತೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2050589 (CK) & #4775526 (legalghost)\n',
#  "You shouldn't be here now.\tನೀವು ಇಲ್ಲಿ ಈಗ ಇರಬಾರದು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3358937 (CK) & #4784819 (legalghost)\n",
#  'He had an accident at work.\tಕೆಲಸದಲ್ಲಿ ಅವನಿಗೆ ಅಪಘಾತವಾಯಿತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #297088 (CK) & #4774758 (legalghost)\n',
#  'I loved going to the beach.\tನಾನು ದಡಕ್ಕೆ ಹೋಗಲು ಇಷ್ಟಪಡುತ್ತಿದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5379492 (Mateon1) & #5387074 (legalghost)\n',
#  'It looks like we got lucky.\tನಮಗೆ ಅದೃಷ್ಟ ಸಿಕ್ಕಿತು ಅಂತ ಅನಿಸುತ್ತೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1897710 (CK) & #4775437 (legalghost)\n',
#  "That's why he lost his job.\tಅದಕ್ಕೇನೇ ಅವನು ಅವನ ಕೆಲಸ ಕಳೆದುಕೊಂಡ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1016597 (CM) & #4774666 (legalghost)\n",
#  'This is a horrible tragedy.\tಇದು ಭಯಾನಕವಾದ ದುರಂತ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4494095 (CK) & #4774649 (legalghost)\n',
#  "We'll think of another way.\tಬೇರೆ ರೀತಿಯಲ್ಲಿ ಯೋಚನೆ ಮಾಡೋಣ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3311967 (CK) & #4784799 (legalghost)\n",
#  'What do you think about it?\tನಿಮಗೆ ಏನು ಅನ್ನಿಸುತ್ತೆ\tCC-BY 2.0 (France) Attribution: tatoeba.org #42939 (CK) & #8903002 (satez416)\n',
#  'I really owe you an apology.\tನಿಜವಾಗಿಯೂ ನಾನು ನಿಮಗೆ ಕ್ಷಮೆ ಕೋರಬೇಕು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2390878 (CK) & #4774664 (legalghost)\n',
#  "I suggest we don't even try.\tನಾವು ಪ್ರಯತ್ನಿಸದೇ ಬೇಡ ಅಂತ ಸೂಚಿಸುತ್ತೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2361707 (CK) & #4774665 (legalghost)\n",
#  'Open your book on page nine.\tನಿಮ್ಮ ಪುಸ್ತಕವನ್ನು ಒಂಬತ್ತನೆಯ ಪುಟಕ್ಕೆ ತೆರೆಯಿರಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3790966 (Eldad) & #4774189 (legalghost)\n',
#  'She brought up two children.\tಅವಳು ಎರಡು ಮಕ್ಕಳನ್ನು ಸಾಕಿದಳು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #316061 (CK) & #4775372 (legalghost)\n',
#  'Tom knew who the killer was.\tಟಾಮಿಗೆ ಯಾರು ಕೊಲೆಗಾರ ಅಂತ ಗೊತ್ತಿತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1093340 (CK) & #4783929 (legalghost)\n',
#  'Where can we find the truth?\tನಾವು ಸತ್ಯವನ್ನು ಎಲ್ಲಿ ಕಂಡುಹಿಡಿಯಬಹುದು?\tCC-BY 2.0 (France) Attribution: tatoeba.org #1818293 (AsliAbbasi) & #4774634 (legalghost)\n',
#  'Have you ever eaten raw fish?\tನೀವು ಯಾವಾಗಲಾದರೂ ಕಚ್ಚಾ ಮೀನು ತಿಂದಿದ್ದೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #271741 (CK) & #4776782 (legalghost)\n',
#  "I'm getting better every day.\tಪ್ರತಿದಿನ ನಾನು ಸುಧಾರಿಸುತ್ತಿದ್ದೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #259790 (CK) & #4776803 (legalghost)\n",
#  "Let's get it right this time.\tಈ ಸಲ ನಾವು ಸರಿಯಾಗಿ ಮಾಡೋಣ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2007418 (CK) & #4784803 (legalghost)\n",
#  'She got married in her teens.\tಅವಳು ಹದಿವಯಸ್ಸಿನಲ್ಲಿ ಮದುವೆಯಾಗಿದಳು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #310061 (CK) & #4776870 (legalghost)\n',
#  "That's not really a solution.\tಅದು ಪರಿಹಾರ ಇಲ್ಲವೇ ಇಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4494014 (CK) & #4774772 (legalghost)\n",
#  'Does Tom have a crush on Mary?\tಟಾಮ್ ಮೇರಿ ಮೇಲೆ ಪ್ರೀತಿ ಇದ್ಯಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #3484688 (CK) & #4776845 (legalghost)\n',
#  'I can recommend a good lawyer.\tನಾನು ನಿಮಗೆ ಒಳ್ಳೆಯ ವಕೀಲರನ್ನು ಸೊಚಿಸಬಹುದು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #
.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1860526 (CK) & #4775394 (legalghost)\n',
#  'Tom stared sadly out the window.\tಟಾಮ್ ಕಿಟಕಿಯ ಹೊರಗೆ ದುಃಖದಿಂದ ನೋಡುತ್ತಲಿರುತ್ತಿದ್ದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2958227 (CK) & #4776865 (legalghost)\n',
#  'Can you suggest another solution?\tಇನ್ನೊಂದು ಪರಿಹಾರವನ್ನು ಸುಚಿಸುತ್ತೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #3127919 (CK) & #4775494 (legalghost)\n',
#  "Don't forget to put out the fire.\tಬೆಂಕಿಯನ್ನು ನಂದಿಸುವುದಕ್ಕೆ ಮರೆಯಬೇಡಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #23860 (CK) & #4776872 (legalghost)\n",
#  "Don't forget to put the fire out.\tಬೆಂಕಿಯನ್ನು ನಂದಿಸುವುದಕ್ಕೆ ಮರೆಯಬೇಡಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #9315351 (CK) & #4776872 (legalghost)\n",
#  'I have enough money to buy a car.\tನನಗೆ ಕಾರನ್ನು ಖರೀದಿಸುವುದಕ್ಕೆ ಸಾಕಷ್ಟು ಹಣವಿದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #258409 (CK) & #4783945 (legalghost)\n',
#  'I wondered the same thing myself.\tಅದೇ ಪ್ರಶ್ನೆ ನನ್ನನ್ನೇ ಕೇಳಿದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2541034 (CK) & #4783951 (legalghost)\n',
#  'Do you want to leave it like that?\tನಿಮಗೆ ಅದನ್ನು ಹಂಗೇ ಬಿಡಬೇಕಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #655682 (CK) & #4783948 (legalghost)\n',
#  'He arrived at the station at five.\tಅವನು ಠಾಣೆಗೆ ಐದು ಗಂಟೆಗೆ ತಲುಪಿದ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #288595 (CK) & #4783920 (legalghost)\n',
#  'I thought the food was too greasy.\tಆಹಾರಕ್ಕೆ ತುಂಬಾ ಎಣ್ಣೆ ಇತ್ತು ಅಂತ ಅನಿಸಿತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4132341 (CK) & #4776840 (legalghost)\n',
#  "It's my fault that you were fired.\tನಿನ್ನನ್ನು ಕೆಲಸದಿಂದ ತೆಗೆದಿರುವುದಕ್ಕೆ ನಾನೇ ಕರಣ ಮತ್ತು ನಂದೇ ತಪ್ಪು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2953143 (CK) & #4776833 (legalghost)\n",
#  'Put it back where you got it from.\tಇದನ್ನು ಎಲ್ಲಿ ಸಿಕ್ಕಿತ್ತೋ ಅಲ್ಲೇ ಇಡು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #41838 (CK) & #4783936 (legalghost)\n',
#  'She treats me as if I were a baby.\tನನ್ನನ್ನು ಎಳೆಮಗು ತರಹ ಪರಿಗಣಿಸುತ್ತಾಳೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #314424 (CK) & #4783939 (legalghost)\n',
#  'The accident caused a traffic jam.\tಅಪಘಾತದ ಕಾರಣದಿಂದ ಸಂಚಾರ ಸ್ತಂಭನ ಇತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #47105 (CK) & #4788530 (legalghost)\n',
#  "These are Tom's glasses, not mine.\tಇದು ಟಾಮಿನ ಕನ್ನಡಕ, ನನ್ನದಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2540429 (CK) & #4776781 (legalghost)\n",
#  "To be honest, I really don't know.\tಪ್ರಾಮಾಣಿಕವಾಗಿ ಹೇಳಬೇಕೆಂದರೆ, ನಾನು ಗೊತ್ತಿಲ್ಲ\tCC-BY 2.0 (France) Attribution: tatoeba.org #4969644 (Suresha) & #4969643 (Suresha)\n",
#  "Tom won't be killing anybody else.\tಟಾಮ್ ಬೇರೆಯಾರನ್ನೂ ಕೊಲ್ಲಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1872430 (CK) & #4776848 (legalghost)\n",
#  'Would you mind my moving your car?\tನಿಮಗೆ ತೊಂದರೆ ಇಲ್ಲವೆಂದರೆ ನಿಮ್ಮ ಕಾರನ್ನು ಜರಗಿಸುತ್ತೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #70587 (CK) & #4776816 (legalghost)\n',
#  'Are you finished reading the paper?\tನೀವು ಪತ್ರಿಕೆಯನ್ನು ಓದಿ ಮುಗಿಸಿದ್ದೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #1446127 (CK) & #4783961 (legalghost)\n',
#  'He bought his daughter a new dress.\tಅವನು ಅವನ ಮಗಳಿಗೆ ಹೊಸ ಬಟ್ಟೆಯನ್ನು ಖರೀದಿಸಿದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #304024 (CK) & #4776786 (legalghost)\n',
#  "Isn't that what we should be doing?\tಅದೇ ನಾವು ಮಾಡ್ಬೇಕು ಅಲ್ಲವ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #4016334 (CK) & #4775463 (legalghost)\n",
#  "They've announced their engagement.\tಅವರು ಅವರ ನಿಶ್ಚಿತಾರ್ಥದವನ್ನು ಪ್ರಕಟಿಸಿದ್ದಾರೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #9649530 (CK) & #4776797 (legalghost)\n",
#  "You can't be in two places at once.\tನಿಮಗೆ ಒಂದೇ ಬಾರಿ ಎರಡು ಜಾಗದಲ್ಲಿ ಇರುವುದಕ್ಕೆ ಆಗಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1950728 (CK) & #4774192 (legalghost)\n",
#  "Are you sure we've never met before?\tನಾವು ಮುಂಚೆ ಎಂದಿಗೂ ಭೇಟಿಯಾಗಿಲ್ಲವೆಂದು ಖಚಿತವಾಗಿ ಹೇಳುತ್ತೀರಾ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2023301 (CK) & #4774632 (legalghost)\n",
#  "Do you know what Tom's last name is?\tಟಮಿನ ಉಪನಾಮ ಏನು ಅಂತ ನಿಮಗೆ ಗೊತ್ತ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #4497587 (CK) & #4776868 (legalghost)\n",
#  "I didn't know that Tom spoke French.\tನನಗೆ ಟಾಮ್ ಫ್ರೆಂಚ್ ಮಾತಾಡುತ್ತಾನೆ ಅಂತ ಗೊತ್ತೇ ಇರಲಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2951980 (CK) & #4775518 (legalghost)\n",
#  'I just want to say that I was wrong.\tನಾನು ತಪ್ಪು ಮಾಡಿದೆ ಎಂದು ಹೇಳಬೇಕು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2018792 (CK) & #4784814 (legalghost)\n',
#  'I no longer feel that way about you.\tನಾನು ನಿನನ್ನು ಇನ್ನು ಮುಂದೆ ಅದೇ ರೀತಿಯಲ್ಲಿ ಭಾವಿಸುವುದಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3818115 (CK) & #4774766 (legalghost)\n',
#  "Let's hope we never have to do that.\tಅದನ್ನು ಎಂದಿಗೂ ಮಾಡಬೇಡವೆಂದು ನಂಬೋಣ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3392646 (CK) & #4783912 (legalghost)\n",
#  'The couple posed for the photograph.\tಜೋಡಿ ಇಬ್ಬರು ಫೋಟೋಗೆ ನಿಲ್ಲಿದರು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #63656 (CK) & #4774670 (legalghost)\n',
#  'What could possibly have gone wrong?\tತಪ್ಪು ಆಗುವುದಕ್ಕೆ ಹೇಗೆ ಸಾಧ್ಯ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #4011833 (CK) & #4774770 (legalghost)\n',
#  'When does Tom usually go to the gym?\tಟಾಮ್ ಸಾಮಾನ್ಯವಾಗಿ ಯಾವಾಗ ಜಿಮ್ಮಿಗೆ ಹೋಗುತ್ತಾನೆ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #3434098 (CK) & #4776852 (legalghost)\n',
#  'I can tell this is difficult for you.\tಇದು ನಿಮಗೆ ಕಷ್ಟವಿದೆ ಎಂದು ನನಗೆ ತಿಳಿದು ಬರುತ್ತದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2301371 (CK) & #4783914 (legalghost)\n',
#  'I made sure that no one was watching.\tಯಾರೂ ನೋಡುತ್ತಿರಲಿಲ್ಲವೆಂದು ನಾನು ಖಚಿತಪಡಿಸಿಕೊಂಡೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #259383 (CK) & #4784815 (legalghost)\n',
#  'It cost twice as much as we expected.\tನಾವು ಎಷ್ಟು ನಿರೀಕ್ಷಿಸುತ್ತಾ ಇದ್ದವೋ ಅದಕ್ಕಿಂತ ಎರಡರಷ್ಟು ಬೆಲೆ ಆಯಿತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4664031 (CK) & #4776858 (legalghost)\n',
#  'She tried to get whatever she wanted.\tಏನೆಲ್ಲಾ ಅವಳಿಗೆ ಬೇಕಿತ್ತೋ ಅದನ್ನು ಖರೀದಿಸುವುದಕ್ಕೆ ಪ್ರಯತ್ನಿಸಿದಳು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #317349 (CK) & #4776860 (legalghost)\n',
#  'She will be relocated to New Zealand.\tಅವಳನ್ನು ನ್ಯೂ ಜಿಲಂಡಿಗೆ ಸ್ಥಳಾಂತರಿಸುತ್ತಾರೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #35958 (CK) & #4783956 (legalghost)\n',
#  'The cause of the accident is unknown.\tಅಪಘಾತದ ಕಾರಣವೇ ಗೊತ್ತಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #263708 (CK) & #4774736 (legalghost)\n',
#  'The story got more and more exciting.\tಆ ಕಥೆ ಇನ್ನಷ್ಟು ಹೆಚ್ಚು ಅದ್ಭುತವಾಯಿತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #319945 (CK) & #4775384 (legalghost)\n',
#  "I don't know how I can ever thank you.\tನಿಮಗೆ ಹೇಗೆ ಧನ್ಯವಾದ ಹೇಳಕ್ಕೆ ಗೊತ್ತಾಗುತ್ತಾ ಇಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3620074 (CK) & #4776836 (legalghost)\n",
#  "Maybe Tom doesn't tell you everything.\tಬಹುಷಃ ಟಾಮ್ ನಿನಗೆ ಎಲ್ಲದರ ಬಗ್ಗೆ ಹೇಳಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3202633 (CK) & #4774760 (legalghost)\n",
#  'She was very bored during the lecture.\tಪ್ರವಚನ ನಡೆಯುತ್ತಿರುವಾಗ ನನಗೆ ತುಂಬಾ ಬೇಸರವಾಗಿತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #241168 (CK) & #4784821 (legalghost)\n',
#  'They failed to fulfill the conditions.\tಅವರು ನಿಯಮಗಳನ್ನು ನೇರವೇರಿಸುವುದಕ್ಕೆ ಆಗಲಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #305806 (CK) & #4776863 (legalghost)\n',
#  "You don't think I can do this, do you?\tನೀನು ಇದನ್ನು ಮಾಡಕ್ಕೆ ಆಗುವುದಿಲ್ಲವೆಂದು ನಂಬಿದ್ದೀಯಾ ಅಲ್ವ?\tCC-BY 2.0 (France) Attribution: tatoeba.org #3360364 (CK) & #4774754 (legalghost)\n",
#  "He couldn't keep his temper any longer.\tಜಾಸ್ತಿ ಹೊತ್ತು ಅವನಿಗೆ ಅವನ ಕೋಪ ತಡೆಯುವುದಕ್ಕೆ ಆಗಲಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #291525 (CK) & #4774645 (legalghost)\n",
#  "Tom promised to help me, but he didn't.\tಟಾಮ್ ಸಹಾಯ ನೀಡುತ್ತಾನೆಂದು ನನಗೆ ಭರವಸೆ ಕೊಟ್ಟನು ಆದರೆ ಕೊಡಲಿಲ್ಲ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3161834 (CK) & #4784808 (legalghost)\n",
#  'It very likely is going to be dangerous.\tಅಪಾಯ ಇರುವುದಕ್ಕೆ ಬಹಳ ಸಾಧ್ಯತೆ ಇದೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3079578 (CK) & #4774193 (legalghost)\n',
#  'Brazil declared war on Argentina in 1825.\tಬ್ರಸಿಲು ಅರ್ಜೆಂಟೀನದ ಮೇಲೆ ಯುದ್ಧವನ್ನು ಪ್ರಕಟಿಸಿದರು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1564880 (CM) & #4774644 (legalghost)\n',
#  'A great deal has happened since that time.\tಅಂದಿನಿಂದ ಬಹಳಷ್ಟು ಘಟನೆಗಳು ನಡೆದಿವೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3131001 (CK) & #4784806 (legalghost)\n',
#  'Where can dollars be exchanged for pounds?\tಎಲ್ಲಿ ಡಾಲರ್ಗಳನ್ನು ಪೌಂಡ್ಸ್ಗೆ ಬದಲಾಯಿಸಬಹುದು?\tCC-BY 2.0 (France) Attribution: tatoeba.org #38191 (fcbond) & #4774616 (legalghost)\n',
#  'A few firefighters suffered minor injuries.\tಕೆಲವೊಂದು ಅಗ್ನಿಶಾಮಕರು ಗಾಯ ಪಟ್ಟರು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5371599 (CK) & #5387094 (legalghost)\n',
#  "I should've gotten up earlier this morning.\tನಾನು ಇವತ್ತು ಬೆಳಿಗ್ಗೆ ಬೇಗ ಏಳಬೇಕಾಗಿತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2406410 (CK) & #4774750 (legalghost)\n",
#  'My father and my brother work in this factory.\tನನ್ನ ತಂದೆ ಹಾಗು ನನ್ನ ಅಣ್ಣ ಈ ಕಾರ್ಖಾನೆಯಲ್ಲಿ ಕೆಲಸ ಮಾಡುತ್ತಾರೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #251611 (CK) & #4776847 (legalghost)\n',
#  'You have to tell me exactly what I need to do.\tನಾನು ಏನನ್ನು ಮಾಡಬೇಕೆಂದು ಸರಿಯಾಗಿ ನೀವು ಹೇಳಬೇಕು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3204603 (CK) & #4776851 (legalghost)\n',
#  "I'll let you know if I find anything interesting.\tಏನೋ ಆಕರ್ಷಕವಾಗಿದ್ದರೆ ನಾನು ನಿನಗೆ ತಿಳಿಸುತ್ತೇನೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1096435 (CK) & #4774684 (legalghost)\n",
#  'There are many new programs to watch this spring.\tಬರುವ ವಸಂತಕಾಲದಲ್ಲಿ ನೋಡುವುದಕ್ಕೆ ಹಲವರು ಕಾರ್ಯಕ್ರಮಗಳು ಇವೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #243101 (CK) & #4783913 (legalghost)\n',
#  "He took charge of the firm after his father's death.\tಅವನ ತಂದೆಯ ಮರಣಾನಂತರ ಅವನು ಸಂಸ್ಥೆಯ ಅಧಿಕಾರ ವಹಿಸಿಕೊಂಡಿದನು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #318903 (CK) & #4775544 (legalghost)\n",
#  'His trip will keep him away from the office for a week.\tಅವನ ಪಯಣ ಅವನನ್ನು ಆಫೀಸಿನಿಂದ ದೂರ ಇಡತ್ತೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #325552 (CK) & #4776541 (legalghost)\n',
#  'They caught sight of the man among the crowd of people.\tಅವರು ಜನಸಮೊಹದ ನಡುವೆ ಅವನನ್ನು ಕಂಡಿದರು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #306934 (CK) & #4776823 (legalghost)\n',
#  'In order to stay awake, I may have to drink more coffee.\tಎಚ್ಚರವಾಗಿರಲು ನಾನು ಇನ್ನು ಸ್ವಲ್ಪ ಕಾಫಿ ಕುಡಿಯಬೇಕು ಅಂತ ಅನಿಸುತ್ತೆ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #322719 (CK) & #4776791 (legalghost)\n',
#  'The only time you talk to me is when you need some money.\tಯಾವಾಗ ನಿನಗೆ ದುಡ್ಡು ಬೇಕಾದರೆ ಮಾತ್ರ ನೀನು ನನ್ನ ಜೊತೆ ಮಾತನಾಡುತ್ತೇಯ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2042689 (CK) & #4774595 (legalghost)\n',
#  'Go to the wine cellar and get a couple of bottles of wine.\tಸರಾಯಿ ನೆಲಮಾಳಿಗೆಗೆ ಹೋಗಿ ಎರಡು ಬಾಟಲಿ ವೈನು ತೆಗೆದುಕೊಂಡು ಬನ್ನಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1860710 (CK) & #4775411 (legalghost)\n',
#  'It was because he was sick that he decided to return home.\tಅವನಿಗೆ ಹುಷಾರು ಇರಲಿಲ್ಲ ಅಂತ ಅವನು ಮನಗೆ ವಾಪಸ್ಸು ಬರವುದಕ್ಕೆ ನಿರ್ದರಿಸಿದ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #283524 (CK) & #4783917 (legalghost)\n',
#  'Both my father and I went to the museum for the first time.\tನಾನು ಮತ್ತು ನನ್ನ ತಂದೆ ಮೊದಲ ಬಾರಿಗೆ ಸಂಗ್ರಾಲಯಕ್ಕೆ ಹೋದ್ವಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #319396 (CK) & #4783980 (legalghost)\n',
#  "You would've gotten away with it if Tom hadn't told on you.\tಒಂದು ವೇಳೆ ಟಾಮ್ ನಿನ್ನ ಬಗ್ಗೆ ಹೇಳಲಿಲ್ಲವೆಂದರೆ ತಪ್ಪಿಸಿಕೊಳ್ಳಬಹುದಾಗಿತ್ತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2537173 (CK) & #4774759 (legalghost)\n",
#  'Any time you want to borrow my car, all you have to do is ask.\tಯಾವಾಗಲಾದರು ನೀವು ನನ್ನ ಕಾರನ್ನು ಬೇಕೆಂದರೆ, ಬರಿ ಕೇಳಿ.\tCC-BY 2.0 (France) Attribution: tatoeba.org #953092 (CK) & #4774604 (legalghost)\n',
#  'I forgot Tom was the one who taught you how to play the guitar.\tಟಾಮ್ ನಿಮಗೆ ಗಿಟಾರ್ ಭಾರಿಸುವುದಕ್ಕೆ ಹೇಳಿಕೊಟ್ಟನೆಂದು ನನಗೆ ಮರೆತುಹೋಯಿತು.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3126715 (CK) & #4784818 (legalghost)\n']

# %%
len(data)
# Out:
# 158

# %%
english_word = []
kannada_word = []
cleaned_data_list = []
for word in data:
  english_word.append(word.split('\t')[:-1][0])
  kannada_word.append(word.split('\t')[:-1][1])
language_data = pd.DataFrame(columns=['English','Kannada'])
language_data['English'] = english_word
language_data['Kannada'] = kannada_word
language_data.to_csv('language_data.csv', index=False)

# %%
language_data.head()
# Out:
#          English           Kannada
# 0     What's up?            ಆರಾಮಾ?
# 1   How are you?         ಹೇಗಿದ್ದೀರ
# 2   Tom woke up.      ಟಾಮ್ ಏಳಿದನು.
# 3  Give me half.   ಅರ್ಧ ನನಗೆ ಕೊಡು.
# 4  We needed it.  ನಮಗೆ ಬೇಕಾಗಿತ್ತು.

# %%
english_text = language_data['English'].values
kannada_text = language_data['Kannada'].values
len(english_text), len(kannada_text)
# Out:
# (158, 158)

# %%
#to lower case
english_text_ = [x.lower() for x in english_text]
kannada_text_ = [x.lower() for x in kannada_text]
#removing inverted commas
english_text_ = [re.sub("'",'',x) for x in english_text_]
kannada_text_ = [re.sub("'",'',x) for x in kannada_text_]
def remove_punc(text_list):
  table = str.maketrans('', '', string.punctuation)
  removed_punc_text = []
  for sent in text_list:
    sentance = [w.translate(table) for w in sent.split(' ')]
    removed_punc_text.append(' '.join(sentance))
  return removed_punc_text
english_text_ = remove_punc(english_text_)
kannada_text_ = remove_punc(kannada_text_)
remove_digits = str.maketrans('', '', digits)
removed_digits_text = []
for sent in english_text_:
  sentance = [w.translate(remove_digits) for w in sent.split(' ')]
  removed_digits_text.append(' '.join(sentance))
english_text_ = removed_digits_text
# removing the digits from the kannada sentances
kannada_text_ = [re.sub("[೧೨೩೪೫೬೭೮೯೦]","",x) for x in kannada_text_]
kannnada_text_ = [re.sub("[\u200d]","",x) for x in kannada_text_]
# removing the stating and ending whitespaces
english_text_ = [x.strip() for x in english_text_]
kannada_text_ = [x.strip() for x in kannada_text_]

# %%
# Adding ‘start’ and ‘end’ tag to kannada sentence.
#This will help the decoder to know from where to start decoding and when to end.
kannada_text_ = ["start " + x + " end" for x in kannada_text_]
# manipulated_kannada_text_
kannada_text_[0], english_text_[0]
# Out:
# ('start ಆರಾಮಾ end', 'whats up')

# %%
X = english_text_
Y = kannada_text_
X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=0.1)

# %%
def Max_length(data):
  max_length_ = max([len(x.split(' ')) for x in data])
  return max_length_
#Training data
max_length_english = Max_length(X_train)
max_length_kannada = Max_length(y_train)
#Test data
max_length_english_test = Max_length(X_test)
max_length_kannada_test = Max_length(y_test)
max_length_kannada, max_length_english
# Out:
# (11, 15)

# %%
englishTokenizer = Tokenizer()
englishTokenizer.fit_on_texts(X_train)
Eword2index = englishTokenizer.word_index
vocab_size_source = len(Eword2index) + 1
X_train = englishTokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(X_train, maxlen=max_length_english, padding='post')
X_test = englishTokenizer.texts_to_sequences(X_test)
X_test = pad_sequences(X_test, maxlen = max_length_english, padding='post')
kannadaTokenizer = Tokenizer()
kannadaTokenizer.fit_on_texts(y_train)
Kword2index = kannadaTokenizer.word_index
vocab_size_target = len(Kword2index) + 1
y_train = kannadaTokenizer.texts_to_sequences(y_train)
y_train = pad_sequences(y_train, maxlen=max_length_kannada, padding='post')
y_test = kannadaTokenizer.texts_to_sequences(y_test)
y_test = pad_sequences(y_test, maxlen = max_length_kannada, padding='post')
vocab_size_source, vocab_size_target
# Out:
# (387, 449)

# %%
#with open('NMT_data.pkl','wb') as f:
  #pkl.dump([X_train, y_train, X_test, y_test],f)
#with open('NMT_Etokenizer.pkl','wb') as f:
  #pkl.dump([vocab_size_source, Eword2index, englishTokenizer], f)
#with open('NMT_Mtokenizer.pkl', 'wb') as f:
  #pkl.dump([vocab_size_target, Kword2index, kannadaTokenizer], f)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
# Attention Mechanism
class AttentionLayer(tf.keras.layers.Layer):
  def __init__(self, units):
    super(AttentionLayer, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # values shape == (batch_size, max_len, hidden size)

    # we are doing this to broadcast addition along the time axis to calculate the score
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
import tensorflow as tf
from tensorflow.python.keras import backend as K

logger = tf.get_logger()

class AttentionLayer(tf.keras.layers.Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs

        logger.debug(f"encoder_out_seq.shape = {encoder_out_seq.shape}")
        logger.debug(f"decoder_out_seq.shape = {decoder_out_seq.shape}")

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            logger.debug("Running energy computation step")

            if not isinstance(states, (list, tuple)):
                raise TypeError(f"States must be an iterable. Got {states} of type {type(states)}")

            encoder_full_seq = states[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_full_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim

            logger.debug(f"U_a_dot_h.shape = {U_a_dot_h.shape}")

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)

            logger.debug(f"Ws_plus_Uh.shape = {Ws_plus_Uh.shape}")

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            logger.debug(f"ei.shape = {e_i.shape}")

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            logger.debug("Running attention vector computation step")

            if not isinstance(states, (list, tuple)):
                raise TypeError(f"States must be an iterable. Got {states} of type {type(states)}")

            encoder_full_seq = states[-1]

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_full_seq * K.expand_dims(inputs, -1), axis=1)

            logger.debug(f"ci.shape = {c_i.shape}")

            return c_i, [c_i]

        # we don't maintain states between steps when computing attention
        # attention is stateless, so we're passing a fake state for RNN step function
        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e], constants=[encoder_out_seq]
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c], constants=[encoder_out_seq]
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.1)

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.1)

# %%
# from attention import AttentionLayer
from keras import backend as K
K.clear_session()
latent_dim = 500
# Encoder
encoder_inputs = Input(shape=(max_length_english,))
enc_emb = Embedding(vocab_size_source, latent_dim,trainable=True)(encoder_inputs)
#LSTM 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)
#LSTM 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)
#LSTM 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
# Set up the decoder.
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(vocab_size_target, latent_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)
#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])
#Attention Layer
attn_layer = AttentionLayer()
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])
# Concat attention output and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])
#Dense layer
decoder_dense = TimeDistributed(Dense(vocab_size_target, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)
# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
plot_model(model, to_file='train_model.png', show_shapes=True)

# %%
model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',

              metrics=['accuracy'])

# %%
history = model.fit([X_train, y_train[:,:-1]], y_train.reshape(y_train.shape[0], y_train.shape[1],1)[:,1:],
                    epochs=300,
                    batch_size=512,
                    validation_data = ([X_test, y_test[:,:-1]],           y_test.reshape(y_test.shape[0], y_test.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/300
# 1/1 [==============================] - 4s 4s/step - loss: 1.6072 - accuracy: 0.5979 - val_loss: 1.9537 - val_accuracy: 0.7437
# Epoch 2/300
# 1/1 [==============================] - 3s 3s/step - loss: 1.6281 - accuracy: 0.5958 - val_loss: 2.0304 - val_accuracy: 0.7375
# Epoch 3/300
# 1/1 [==============================] - 4s 4s/step - loss: 1.6672 - accuracy: 0.5838 - val_loss: 2.0617 - val_accuracy: 0.7125
# Epoch 4/300
# 1/1 [==============================] - 3s 3s/step - loss: 1
300
# 1/1 [==============================] - 4s 4s/step - loss: 0.2341 - accuracy: 0.9641 - val_loss: 3.2805 - val_accuracy: 0.6687
# Epoch 292/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.2391 - accuracy: 0.9613 - val_loss: 3.1998 - val_accuracy: 0.6750
# Epoch 293/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.2334 - accuracy: 0.9627 - val_loss: 3.2924 - val_accuracy: 0.6687
# Epoch 294/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.2356 - accuracy: 0.9599 - val_loss: 3.1994 - val_accuracy: 0.6875
# Epoch 295/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.2319 - accuracy: 0.9634 - val_loss: 3.2817 - val_accuracy: 0.6687
# Epoch 296/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.2284 - accuracy: 0.9570 - val_loss: 3.1877 - val_accuracy: 0.6812
# Epoch 297/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.2307 - accuracy: 0.9514 - val_loss: 3.2934 - val_accuracy: 0.6687
# Epoch 298/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.2132 - accuracy: 0.9648 - val_loss: 3.1719 - val_accuracy: 0.6750
# Epoch 299/300
# 1/1 [==============================] - 4s 4s/step - loss: 0.2079 - accuracy: 0.9718 - val_loss: 3.3285 - val_accuracy: 0.6625
# Epoch 300/300
# 1/1 [==============================] - 3s 3s/step - loss: 0.2100 - accuracy: 0.9704 - val_loss: 3.1648 - val_accuracy: 0.6875

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
model_json = model.to_json()
with open("NMT_model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("NMT_model_weight.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# loading the model architecture and asigning the weights
json_file = open('NMT_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model_loaded = model_from_json(loaded_model_json, custom_objects={'AttentionLayer': AttentionLayer})
# load weights into new model
model_loaded.load_weights("NMT_model_weight.h5")

# %%
latent_dim=500
# encoder inference
encoder_inputs = model_loaded.input[0]  #loading encoder_inputs
encoder_outputs, state_h, state_c = model_loaded.layers[6].output #loading encoder_outputs
#print(encoder_outputs.shape)
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])
# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(15,latent_dim))
# Get the embeddings of the decoder sequence
decoder_inputs = model_loaded.layers[3].output
#print(decoder_inputs.shape)
dec_emb_layer = model_loaded.layers[5]
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_lstm = model_loaded.layers[7]
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])
#attention inference
attn_layer = model_loaded.layers[8]
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
concate = model_loaded.layers[9]
decoder_inf_concat = concate([decoder_outputs2, attn_out_inf])
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_dense = model_loaded.layers[10]
decoder_outputs2 = decoder_dense(decoder_inf_concat)
# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))

    # Choose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = Kword2index['start']

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])

        if sampled_token_index == 0:
            break
        else:
            sampled_token = Kindex2word[sampled_token_index]
            if sampled_token != 'end':
                decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find stop word.
        if sampled_token == 'end' or len(decoded_sentence.split()) >= (26-1):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
Eindex2word = englishTokenizer.index_word
Kindex2word = kannadaTokenizer.index_word

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=Kword2index['start']) and i!=Kword2index['end']):
        newString=newString+Kindex2word[i]+' '
    return newString
def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+Eindex2word[i]+' '
    return newString

# %%
for i in range(10):
  print("Review:",seq2text(X_test[i]))
  print("Original summary:",seq2summary(y_test[i]))
  print(X_test[i].shape)
  print("Predicted summary:",decode_sequence(X_test[i].reshape(1,15)))
  print("\n")
# Out:
# Review: lets we never have to do that
# Original summary: ಅದನ್ನು ಎಂದಿಗೂ
# (15,)
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# Predicted summary:  ನಾವು ಮುಂಚೆ ಎಂದಿಗೂ ಭೇಟಿಯಾಗಿಲ್ಲವೆಂದು ಖಚಿತವಾಗಿ ಹೇಳುತ್ತೀರಾ
#
#
# Review: he every
# Original summary: ಅವನು ಹೋಗುತ್ತಾನೆ
# (15,)
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  ನಿಮ್ಮ ಮನೇಲಿ ಹೆಂಗಿದ್ದಾರೆ
#
#
# Review: see you at
# Original summary: ಎರಡು ನಿನ್ನನ್ನು
# (15,)
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  ಅರ್ಧ ನನಗೆ ಕೊಡು
#
#
# Review: i dont know what me
# Original summary: ನನಗೆ ಅಂತ ಗೊತ್ತಿಲ್ಲ
# (15,)
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  ನೆನ್ನೆ ರಾತ್ರಿ ಹೇಗೆ ಅಂತ ಸೂಚಿಸುತ್ತೇನೆ
#
#
# Review: tom out the
# Original summary: ಟಾಮ್
# (15,)
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  ಟಾಮ್ ಮೂರು ಗಂಟೆಯ ಮುಂಚೇನೇ ಹೋದ
#
#
# Review: i only to help you
# Original summary: ಸಹಾಯ
# (15,)
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  ನಾನು ದಡಕ್ಕೆ ಹೋಗಲು ಇಷ್ಟಪಡುತ್ತಿದೆ
#
#
# Review: dont let tom do it
# Original summary: ಟೊಮನ್ನು ಅದನ್ನು ಮಾಡಕ್ಕೆ
# (15,)
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  ನಿಮಗೆ ನೆನಪು ಇದ್ಯಾ
#
#
# Review: we should the
# Original summary: ನಾವು
# (15,)
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# Predicted summary:  ಆರಾಮಾ
#
#
# Review: what do you think about it
# Original summary: ನಿಮಗೆ ಏನು
# (15,)
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted summary:  ನನಗೆ ಪ್ರಯತ್ನಿಸದೇ ಬೇಡ ಅಂತ ಅಂತ ಗೊತ್ತೇ ಇರಲಿಲ್ಲ
#
#
# Review: i the was
# Original summary: ತುಂಬಾ ಇತ್ತು ಅಂತ
# (15,)
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted summary:  ನಾನು ತುಂಬಾ ಬಿಝಿ
