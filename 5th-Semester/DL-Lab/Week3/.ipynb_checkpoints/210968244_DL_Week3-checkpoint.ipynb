# %% [markdown]
# # WEEK 3
# ### CONVOLUTIONAL NUERAL NETWORKS
# ## VS
# ### FULLY CONNECTED NEURAL NETWORKS

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Name : Kartabya Krishna
# # Date : 20230817
# # Batch : B2

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Importing required libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.activations import relu , softmax
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from keras.utils import to_categorical, plot_model
from keras.datasets import mnist
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix, classification_report
import cv2 as cv

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# #### Importing the data

# %%
df=tf.keras.datasets.fashion_mnist
(x_train,y_train),(x_test,y_test)=df.load_data()

# %% [markdown]
# #### Metadata of MNIST Dataset

# %% [markdown]
# ## Q1) Understanding the Dataset and Pre-processing:

# %%
print("Fashion MNIST Dataset:")
print("Number of training samples:", x_train.shape[0])
print("Number of test samples:", x_test.shape[0])
print("Image shape:", x_train[0].shape)
print("Number of classes:", len(set(y_train)))
# Out:
# Fashion MNIST Dataset:
# Number of training samples: 60000
# Number of test samples: 10000
# Image shape: (28, 28)
# Number of classes: 10

# %% [markdown]
# #### Exploratory Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist

# Display one sample image from each class
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", 
           "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

plt.figure(figsize=(10, 10))

for class_index in range(len(classes)):
    class_samples = np.where(y_train == class_index)[0]
    sample_index = class_samples[0]  # Get the first sample of the current class
    plt.subplot(5, 5, class_index + 1)
    plt.imshow(x_train[sample_index], cmap='gray')
    plt.title(classes[class_index])
    plt.axis('off')

plt.tight_layout()
plt.show()

# Display the distribution of classes
class_counts = np.bincount(y_train)
plt.bar(classes, class_counts)
plt.xticks(rotation=45)
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.title('Distribution of Classes in Fashion MNIST')
plt.tight_layout()
plt.show()

# Display a random image from the dataset
random_index = np.random.randint(0, len(x_train))
plt.imshow(x_train[random_index], cmap='gray')
plt.title(f"Random Image: {classes[y_train[random_index]]}")
plt.axis('off')
plt.show()

# %%
# Display the dimensions of each image
for i in range(len(x_train)):
    print(f"Image {i + 1} dimensions: {x_train[i].shape}")
# Out:
# Image 1 dimensions: (28, 28)
# Image 2 dimensions: (28, 28)
# Image 3 dimensions: (28, 28)
# Image 4 dimensions: (28, 28)
# Image 5 dimensions: (28, 28)
# Image 6 dimensions: (28, 28)
# Image 7 dimensions: (28, 28)
# Image 8 dimensions: (28, 28)
# Image 9 dimensions: (28, 28)
# Image 10 dimensions: (28, 28)
# Image 11 dimensions: (28, 28)
# Image 12 dimensions: (28, 28)
# Image 13 dimensions: (28, 28)
# Image 14 dimensions: (28, 28)
# Image 15 dimensions: (28, 28)
# Image 16 dimensions: (28, 28)
# Image 17 dimensions: (28, 28)
# Image 18 dimensions: (28, 28)
# Image 19 dimensions: (28, 28)
# Image 20 dimensions: (28, 28)
# Image 21 dimensions: (28, 28)
# Image 22 dimensions: (28, 28)
# Image 23 dimensions: (28, 28)
# Image 24 dimensions: (28, 28)
# Image 25 dimensions: (28, 28)
# Image 26 dimensions: (28, 28)
# Image 27 dimensions: (28, 28)
# Image 28 dimensions: (28, 28)
# Image 29 dimensions: (28, 28)
# Image 30 dimensions: (28, 28)
# Image 31 dimensions: (28, 28)
# Image 32 dimensions: (28, 28)
# Image 33 dimensions: (28, 28)
# Image 34 dimensions: (28, 28)
# Image 35 dimensions: (28, 28)
# Image 36 dimensions: (28, 28)
# Image 37 dimensions: (28, 28)
# Image 38 dimensions: (28, 28)
# Image 39 dimensions: (28, 28)
# Image 40 dimensions: (28, 28)
# Image 41 dimensions: (28, 28)
# Image 42 dimensions: (28, 28)
# Image 43 dimensions: (28, 28)
# Image 44 dimensions: (28, 28)
# Image 45 dimensions: (28, 28)
# Image 46 dimensions: (28, 28)
# Image 47 dimensions: (28, 28)
# Image 48 dimensions: (28, 28)
# Image 49 dimensions: (28, 28)
# Image 50 dimensions: (28, 28)
# Image 51 dimensions: (28, 28)
# Image 52 dimensions: (28, 28)
# Image 53 dimensions: (28, 28)
# Image 54 dimensions: (28, 28)
# Image 55 dimensions: (28, 28)
# Image 56 dimensions: (28, 28)
# Image 57 dimensions: (28, 28)
# Image 58 dimensions: (28, 28)
# Image 59 dimensions: (28, 28)
# Image 60 dimensions: (28, 28)
# Image 61 dimensions: (28, 28)
# Image 62 dimensions: (28, 28)
# Image 63 dimensions: (28, 28)
# Image 64 dimensions: (28, 28)
# Image 65 dimensions: (28, 28)
# Image 66 dimensions: (28, 28)
# Image 67 dimensions: (28, 28)
# Image 68 dimensions: (28, 28)
# Image 69 dimensions: (28, 28)
# Image 70 dimensions: (28, 28)
# Image 71 dimensions: (28, 28)
# Image 72 dimensions: (28, 28)
# Image 73 dimensions: (28, 28)
# Image 74 dimensions: (28, 28)
# Image 75 dimensions: (28, 28)
# Image 76 dimensions: (28, 28)
# Image 77 dimensions: (28, 28)
# Image 78 dimensions: (28, 28)
# Image 79 dimensions: (28, 28)
# Image 80 dimensions: (28, 28)
# Image 81 dimensions: (28, 28)
# Image 82 dimensions: (28, 28)
# Image 83 dimensions: (28, 28)
# Image 84 dimensions: (28, 28)
# Image 85 dimensions: (28, 28)
# Image 86 dimensions: (28, 28)
# Image 87 dimensions: (28, 28)
# Image 88 dimensions: (28, 28)
# Image 89 dimensions: (28, 28)
# Image 90 dimensions: (28, 28)
# Image 91 dimensions: (28, 28)
# Image 92 dimensions: (28, 28)
# Image 93 dimensions: (28, 28)
# Image 94 dimensions: (28, 28)
# Image 95 dimensions: (28, 28)
# Image 96 dimensions: (28, 28)
# Image 97 dimensions: (28, 28)
# Image 98 dimensions: (28, 28)
# Image 99 dimensions: (28, 28)
# Image 100 dimensions: (28, 28)
# Image 101 dimensions: (28, 28)
# Image 102 dimensions: (28, 28)
# Image 103 dimensions: (28, 28)
# Image 104 dimensions: (28, 28)
# Image 105 dimensions: (28, 28)
# Image 106 dimensions: (28, 28)
# Image 107 dimensions: (28, 28)
# Image 108 dimensions: (28, 28)
# Image 109 dimensions: (28, 28)
# Image 110 dimensions: (28, 28)
# Image 111 dimensions: (28, 28)
# Image 112 dimensions: (28, 28)
# Image 113 dimensions: (28, 28)
# Image 114 dimensions: (28, 28)
# Image 115 dimensions: (28, 28)
# Image 116 dimensions: (28, 28)
# Image 117 dimensions: (28, 28)
# Image 118 dimensions: (28, 28)
# Image 119 dimensions: (28, 28)
# Image 120 dimensions: (28, 28)
# Image 121 dimensions: (28, 28)
# Image 122 dimensions: (28, 28)
# Image 123 dimensions: (28, 28)
# Image 124 dimensions: (28, 28)
# Image 125 dimensions: (28, 28)
# Image 126 dimensions: (28, 28)
# Image 127 dimensions: (28, 28)
# Image 128 dimensions: (28, 28)
# Image 129 dimensions: (28, 28)
# Image 130 dimensions: (28, 28)
# Image 131 dimensions: (28, 28)
# Image 132 dimensions: (28, 28)
# Image 133 dimensions: (28, 28)
# Image 134 dimensions: (28, 28)
# Image 135 dimensions: (28, 28)
# Image 136 dimensions: (28, 28)
# Image 137 dimensions: (28, 28)
# Image 138 dimensions: (28, 28)
# Image 139 dimensions: (28, 28)
# Image 140 dimensions: (28, 28)
# Image 141 dimensions: (28, 28)
# Image 142 dimensions: (28, 28)
# Image 143 dimensions: (28, 28)
# Image 144 dimensions: (28, 28)
# Image 145 dimensions: (28, 28)
# Image 146 dimensions: (28, 28)
# Image 147 dimensions: (28, 28)
# Image 148 dimensions: (28, 28)
# Image 149 dimensions: (28, 28)
# Image 150 dimensions: (28, 28)
# Image 151 dimensions: (28, 28)
# Image 152 dimensions: (28, 28)
# Image 153 dimensions: (28, 28)
# Image 154 dimensions: (28, 28)
# Image 155 dimensions: (28, 28)
# Image 156 dimensions: (28, 28)
# Image 157 dimensions: (28, 28)
# Image 158 dimensions: (28, 28)
# Image 159 dimensions: (28, 28)
# Image 160 dimensions: (28, 28)
# Image 161 dimensions: (28, 28)
# Image 162 dimensions: (28, 28)
# Image 163 dimensions: (28, 28)
# Image 164 dimensions: (28, 28)
# Image 165 dimensions: (28, 28)
# Image 166 dimensions: (28, 28)
# Image 167 dimensions: (28, 28)
# Image 168 dimensions: (28, 28)
# Image 169 dimensions: (28, 28)
# Image 170 dimensions: (28, 28)
# Image 171 dimensions: (28, 28)
# Image 172 dimensions: (28, 28)
# Image 173 dimensions: (28, 28)
# Image 174 dimensions: (28, 28)
# Image 175 dimensions: (28, 28)
# Image 176 dimensions: (28, 28)
# Image 177 dimensions: (28, 28)
# Image 178 dimensions: (28, 28)
# Image 179 dimensions: (28, 28)
# Image 180 dimensions: (28, 28)
# Image 181 dimensions: (28, 28)
# Image 182 dimensions: (28, 28)
# Image 183 dimensions: (28, 28)
# Image 184 dimensions: (28, 28)
# Image 185 dimensions: (28, 28)
# Image 186 dimensions: (28, 28)
# Image 187 dimensions: (28, 28)
# Image 188 dimensions: (28, 28)
# Image 189 dimensions: (28, 28)
# Image 190 dimensions: (28, 28)
# Image 191 dimensions: (28, 28)
# Image 192 dimensions: (28, 28)
# Image 193 dimensions: (28, 28)
# Image 194 dimensions: (28, 28)
# Image 195 dimensions: (28, 28)
# Image 196 dimensions: (28, 28)
# Image 197 dimensions: (28, 28)
# Image 198 dimensions: (28, 28)
# Image 199 dimensions: (28, 28)
# Image 200 dimensions: (28, 28)
# Image 201 dimensions: (28, 28)
# Image 202 dimensions: (28, 28)
# Image 203 dimensions: (28, 28)
# Image 204 dimensions: (28, 28)
# Image 205 dimensions: (28, 28)
# Image 206 dimensions: (28, 28)
# Image 207 dimensions: (28, 28)
# Image 208 dimensions: (28, 28)
# Image 209 dimensions: (28, 28)
# Image 210 dimensions: (28, 28)
# Image 211 dimensions: (28, 28)
# Image 212 dimensions: (28, 28)
# Image 213 dimensions: (28, 28)
# Image 214 dimensions: (28, 28)
# Image 215 dimensions: (28, 28)
# Image 216 dimensions: (28, 28)
# Image 217 dimensions: (28, 28)
# Image 218 dimensions: (28, 28)
# Image 219 dimensions: (28, 28)
# Image 220 dimensions: (28, 28)
# Image 221 dimensions: (28, 28)
# Image 222 dimensions: (28, 28)
# Image 223 dimensions: (28, 28)
# Image 224 dimensions: (28, 28)
# Image 225 dimensions: (28, 28)
# Image 226 dimensions: (28, 28)
# Image 227 dimensions: (28, 28)
# Image 228 dimensions: (28, 28)
# Image 229 dimensions: (28, 28)
# Image 230 dimensions: (28, 28)
# Image 231 dimensions: (28, 28)
# Image 232 dimensions: (28, 28)
# Image 233 dimensions: (28, 28)
# Image 234 dimensions: (28, 28)
# Image 235 dimensions: (28, 28)
# Image 236 dimensions: (28, 28)
# Image 237 dimensions: (28, 28)
# Image 238 dimensions: (28, 28)
# Image 239 dimensions: (28, 28)
# Image 240 dimensions: (28, 28)
# Image 241 dimensions: (28, 28)
# Image 242 dimensions: (28, 28)
# Image 243 dimensions: (28, 28)
# Image 244 dimensions: (28, 28)
# Image 245 dimensions: (28, 28)
# Image 246 dimensions: (28, 28)
# Image 247 dimensions: (28, 28)
# Image 248 dimensions: (28, 28)
# Image 249 dimensions: (28, 28)
# Image 250 dimensions: (28, 28)
# Image 251 dimensions: (28, 28)
# Image 252 dimensions: (28, 28)
# Image 253 dimensions: (28, 28)
# Image 254 dimensions: (28, 28)
# Image 255 dimensions: (28, 28)
# Image 256 dimensions: (28, 28)
# Image 257 dimensions: (28, 28)
# Image 258 dimensions: (28, 28)
# Image 259 dimensions: (28, 28)
# Image 260 dimensions: (28, 28)
# Image 261 dimensions: (28, 28)
# Image 262 dimensions: (28, 28)
# Image 263 dimensions: (28, 28)
# Image 264 dimensions: (28, 28)
# Image 265 dimensions: (28, 28)
# Image 266 dimensions: (28, 28)
# Image 267 dimensions: (28, 28)
# Image 268 dimensions: (28, 28)
# Image 269 dimensions: (28, 28)
# Image 270 dimensions: (28, 28)
# Image 271 dimensions: (28, 28)
# Image 272 dimensions: (28, 28)
# Image 273 dimensions: (28, 28)
# Image 274 dimensions: (28, 28)
# Image 275 dimensions: (28, 28)
# Image 276 dimensions: (28, 28)
# Image 277 dimensions: (28, 28)
# Image 278 dimensions: (28, 28)
# Image 279 dimensions: (28, 28)
# Image 280 dimensions: (28, 28)
# Image 281 dimensions: (28, 28)
# Image 282 dimensions: (28, 28)
# Image 283 dimensions: (28, 28)
# Image 284 dimensions: (28, 28)
# Image 285 dimensions: (28, 28)
# Image 286 dimensions: (28, 28)
# Image 287 dimensions: (28, 28)
# Image 288 dimensions: (28, 28)
# Image 289 dimensions: (28, 28)
# Image 290 dimensions: (28, 28)
# Image 291 dimensions: (28, 28)
# Image 292 dimensions: (28, 28)
# Image 293 dimensions: (28, 28)
# Image 294 dimensions: (28, 28)
# Image 295 dimensions: (28, 28)
# Image 296 dimensions: (28, 28)
# Image 297 dimensions: (28, 28)
# Image 298 dimensions: (28, 28)
# Image 299 dimensions: (28, 28)
# Image 300 dimensions: (28, 28)
# Image 301 dimensions: (28, 28)
# Image 302 dimensions: (28, 28)
# Image 303 dimensions: (28, 28)
# Image 304 dimensions: (28, 28)
# Image 305 dimensions: (28, 28)
# Image 306 dimensions: (28, 28)
# Image 307 dimensions: (28, 28)
# Image 308 dimensions: (28, 28)
# Image 309 dimensions: (28, 28)
# Image 310 dimensions: (28, 28)
# Image 311 dimensions: (28, 28)
# Image 312 dimensions: (28, 28)
# Image 313 dimensions: (28, 28)
# Image 314 dimensions: (28, 28)
# Image 315 dimensions: (28, 28)
# Image 316 dimensions: (28, 28)
# Image 317 dimensions: (28, 28)
# Image 318 dimensions: (28, 28)
# Image 319 dimensions: (28, 28)
# Image 320 dimensions: (28, 28)
# Image 321 dimensions: (28, 28)
# Image 322 dimensions: (28, 28)
# Image 323 dimensions: (28, 28)
# Image 324 dimensions: (28, 28)
# Image 325 dimensions: (28, 28)
# Image 326 dimensions: (28, 28)
# Image 327 dimensions: (28, 28)
# Image 328 dimensions: (28, 28)
# Image 329 dimensions: (28, 28)
# Image 330 dimensions: (28, 28)
# Image 331 dimensions: (28, 28)
# Image 332 dimensions: (28, 28)
# Image 333 dimensions: (28, 28)
# Image 334 dimensions: (28, 28)
# Image 335 dimensions: (28, 28)
# Image 336 dimensions: (28, 28)
# Image 337 dimensions: (28, 28)
# Image 338 dimensions: (28, 28)
# Image 339 dimensions: (28, 28)
# Image 340 dimensions: (28, 28)
# Image 341 dimensions: (28, 28)
# Image 342 dimensions: (28, 28)
# Image 343 dimensions: (28, 28)
# Image 344 dimensions: (28, 28)
# Image 345 dimensions: (28, 28)
# Image 346 dimensions: (28, 28)
# Image 347 dimensions: (28, 28)
# Image 348 dimensions: (28, 28)
# Image 349 dimensions: (28, 28)
# Image 350 dimensions: (28, 28)
# Image 351 dimensions: (28, 28)
# Image 352 dimensions: (28, 28)
# Image 353 dimensions: (28, 28)
# Image 354 dimensions: (28, 28)
# Image 355 dimensions: (28, 28)
# Image 356 dimensions: (28, 28)
# Image 357 dimensions: (28, 28)
# Image 358 dimensions: (28, 28)
# Image 359 dimensions: (28, 28)
# Image 360 dimensions: (28, 28)
# Image 361 dimensions: (28, 28)
# Image 362 dimensions: (28, 28)
# Image 363 dimensions: (28, 28)
# Image 364 dimensions: (28, 28)
# Image 365 dimensions: (28, 28)
# Image 366 dimensions: (28, 28)
# Image 367 dimensions: (28, 28)
# Image 368 dimensions: (28, 28)
# Image 369 dimensions: (28, 28)
# Image 370 dimensions: (28, 28)
# Image 371 dimensions: (28, 28)
# Image 372 dimensions: (28, 28)
# Image 373 dimensions: (28, 28)
# Image 374 dimensions: (28, 28)
# Image 375 dimensions: (28, 28)
# Image 376 dimensions: (28, 28)
# Image 377 dimensions: (28, 28)
# Image 378 dimensions: (28, 28)
# Image 379 dimensions: (28, 28)
# Image 380 dimensions: (28, 28)
# Image 381 dimensions: (28, 28)
# Image 382 dimensions: (28, 28)
# Image 383 dimensions: (28, 28)
# Image 384 dimensions: (28, 28)
# Image 385 dimensions: (28, 28)
# Image 386 dimensions: (28, 28)
# Image 387 dimensions: (28, 28)
# Image 388 dimensions: (28, 28)
# Image 389 dimensions: (28, 28)
# Image 390 dimensions: (28, 28)
# Image 391 dimensions: (28, 28)
# Image 392 dimensions: (28, 28)
# Image 393 dimensions: (28, 28)
# Image 394 dimensions: (28, 28)
# Image 395 dimensions: (28, 28)
# Image 396 dimensions: (28, 28)
# Image 397 dimensions: (28, 28)
# Image 398 dimensions: (28, 28)
# Image 399 dimensions: (28, 28)
# Image 400 dimensions: (28, 28)
# Image 401 dimensions: (28, 28)
# Image 402 dimensions: (28, 28)
# Image 403 dimensions: (28, 28)
# Image 404 dimensions: (28, 28)
# Image 405 dimensions: (28, 28)
# Image 406 dimensions: (28, 28)
# Image 407 dimensions: (28, 28)
# Image 408 dimensions: (28, 28)
# Image 409 dimensions: (28, 28)
# Image 410 dimensions: (28, 28)
# Image 411 dimensions: (28, 28)
# Image 412 dimensions: (28, 28)
# Image 413 dimensions: (28, 28)
# Image 414 dimensions: (28, 28)
# Image 415 dimensions: (28, 28)
# Image 416 dimensions: (28, 28)
# Image 417 dimensions: (28, 28)
# Image 418 dimensions: (28, 28)
# Image 419 dimensions: (28, 28)
# Image 420 dimensions: (28, 28)
# Image 421 dimensions: (28, 28)
# Image 422 dimensions: (28, 28)
# Image 423 dimensions: (28, 28)
# Image 424 dimensions: (28, 28)
# Image 425 dimensions: (28, 28)
# Image 426 dimensions: (28, 28)
# Image 427 dimensions: (28, 28)
# Image 428 dimensions: (28, 28)
# Image 429 dimensions: (28, 28)
# Image 430 dimensions: (28, 28)
# Image 431 dimensions: (28, 28)
# Image 432 dimensions: (28, 28)
# Image 433 dimensions: (28, 28)
# Image 434 dimensions: (28, 28)
# Image 435 dimensions: (28, 28)
# Image 436 dimensions: (28, 28)
# Image 437 dimensions: (28, 28)
# Image 438 dimensions: (28, 28)
# Image 439 dimensions: (28, 28)
# Image 440 dimensions: (28, 28)
# Image 441 dimensions: (28, 28)
# Image 442 dimensions: (28, 28)
# Image 443 dimensions: (28, 28)
# Image 444 dimensions: (28, 28)
# Image 445 dimensions: (28, 28)
# Image 446 dimensions: (28, 28)
# Image 447 dimensions: (28, 28)
# Image 448 dimensions: (28, 28)
# Image 449 dimensions: (28, 28)
# Image 450 dimensions: (28, 28)
# Image 451 dimensions: (28, 28)
# Image 452 dimensions: (28, 28)
# Image 453 dimensions: (28, 28)
# Image 454 dimensions: (28, 28)
# Image 455 dimensions: (28, 28)
# Image 456 dimensions: (28, 28)
# Image 457 dimensions: (28, 28)
# Image 458 dimensions: (28, 28)
# Image 459 dimensions: (28, 28)
# Image 460 dimensions: (28, 28)
# Image 461 dimensions: (28, 28)
# Image 462 dimensions: (28, 28)
# Image 463 dimensions: (28, 28)
# Image 464 dimensions: (28, 28)
# Image 465 dimensions: (28, 28)
# Image 466 dimensions: (28, 28)
# Image 467 dimensions: (28, 28)
# Image 468 dimensions: (28, 28)
# Image 469 dimensions: (28, 28)
# Image 470 dimensions: (28, 28)
# Image 471 dimensions: (28, 28)
# Image 472 dimensions: (28, 28)
# Image 473 dimensions: (28, 28)
# Image 474 dimensions: (28, 28)
# Image 475 dimensions: (28, 28)
# Image 476 dimensions: (28, 28)
# Image 477 dimensions: (28, 28)
# Image 478 dimensions: (28, 28)
# Image 479 dimensions: (28, 28)
# Image 480 dimensions: (28, 28)
# Image 481 dimensions: (28, 28)
# Image 482 dimensions: (28, 28)
# Image 483 dimensions: (28, 28)
# Image 484 dimensions: (28, 28)
# Image 485 dimensions: (28, 28)
# Image 486 dimensions: (28, 28)
# Image 487 dimensions: (28, 28)
# Image 488 dimensions: (28, 28)
# Image 489 dimensions: (28, 28)
# Image 490 dimensions: (28, 28)
# Image 491 dimensions: (28, 28)
# Image 492 dimensions: (28, 28)
# Image 493 dimensions: (28, 28)
# Image 494 dimensions: (28, 28)
# Image 495 dimensions: (28, 28)
# Image 496 dimensions: (28, 28)
# Image 497 dimensions: (28, 28)
# Image 498 dimensions: (28, 28)
# Image 499 dimensions: (28, 28)
# Image 500 dimensions: (28, 28)
# Image 501 dimensions: (28, 28)
# Image 502 dimensions: (28, 28)
# Image 503 dimensions: (28, 28)
# Image 504 dimensions: (28, 28)
# Image 505 dimensions: (28, 28)
# Image 506 dimensions: (28, 28)
# Image 507 dimensions: (28, 28)
# Image 508 dimensions: (28, 28)
# Image 509 dimensions: (28, 28)
# Image 510 dimensions: (28, 28)
# Image 511 dimensions: (28, 28)
# Image 512 dimensions: (28, 28)
# Image 513 dimensions: (28, 28)
# Image 514 dimensions: (28, 28)
# Image 515 dimensions: (28, 28)
# Image 516 dimensions: (28, 28)
# Image 517 dimensions: (28, 28)
# Image 518 dimensions: (28, 28)
# Image 519 dimensions: (28, 28)
# Image 520 dimensions: (28, 28)
# Image 521 dimensions: (28, 28)
# Image 522 dimensions: (28, 28)
# Image 523 dimensions: (28, 28)
# Image 524 dimensions: (28, 28)
# Image 525 dimensions: (28, 28)
# Image 526 dimensions: (28, 28)
# Image 527 dimensions: (28, 28)
# Image 528 dimensions: (28, 28)
# Image 529 dimensions: (28, 28)
# Image 530 dimensions: (28, 28)
# Image 531 dimensions: (28, 28)
# Image 532 dimensions: (28, 28)
# Image 533 dimensions: (28, 28)
# Image 534 dimensions: (28, 28)
# Image 535 dimensions: (28, 28)
# Image 536 dimensions: (28, 28)
# Image 537 dimensions: (28, 28)
# Image 538 dimensions: (28, 28)
# Image 539 dimensions: (28, 28)
# Image 540 dimensions: (28, 28)
# Image 541 dimensions: (28, 28)
# Image 542 dimensions: (28, 28)
# Image 543 dimensions: (28, 28)
# Image 544 dimensions: (28, 28)
# Image 545 dimensions: (28, 28)
# Image 546 dimensions: (28, 28)
# Image 547 dimensions: (28, 28)
# Image 548 dimensions: (28, 28)
# Image 549 dimensions: (28, 28)
# Image 550 dimensions: (28, 28)
# Image 551 dimensions: (28, 28)
# Image 552 dimensions: (28, 28)
# Image 553 dimensions: (28, 28)
# Image 554 dimensions: (28, 28)
# Image 555 dimensions: (28, 28)
# Image 556 dimensions: (28, 28)
# Image 557 dimensions: (28, 28)
# Image 558 dimensions: (28, 28)
# Image 559 dimensions: (28, 28)
# Image 560 dimensions: (28, 28)
# Image 561 dimensions: (28, 28)
# Image 562 dimensions: (28, 28)
# Image 563 dimensions: (28, 28)
# Image 564 dimensions: (28, 28)
# Image 565 dimensions: (28, 28)
# Image 566 dimensions: (28, 28)
# Image 567 dimensions: (28, 28)
# Image 568 dimensions: (28, 28)
# Image 569 dimensions: (28, 28)
# Image 570 dimensions: (28, 28)
# Image 571 dimensions: (28, 28)
# Image 572 dimensions: (28, 28)
# Image 573 dimensions: (28, 28)
# Image 574 dimensions: (28, 28)
# Image 575 dimensions: (28, 28)
# Image 576 dimensions: (28, 28)
# Image 577 dimensions: (28, 28)
# Image 578 dimensions: (28, 28)
# Image 579 dimensions: (28, 28)
# Image 580 dimensions: (28, 28)
# Image 581 dimensions: (28, 28)
# Image 582 dimensions: (28, 28)
# Image 583 dimensions: (28, 28)
# Image 584 dimensions: (28, 28)
# Image 585 dimensions: (28, 28)
# Image 586 dimensions: (28, 28)
# Image 587 dimensions: (28, 28)
# Image 588 dimensions: (28, 28)
# Image 589 dimensions: (28, 28)
# Image 590 dimensions: (28, 28)
# Image 591 dimensions: (28, 28)
# Image 592 dimensions: (28, 28)
# Image 593 dimensions: (28, 28)
# Image 594 dimensions: (28, 28)
# Image 595 dimensions: (28, 28)
# Image 596 dimensions: (28, 28)
# Image 597 dimensions: (28, 28)
# Image 598 dimensions: (28, 28)
# Image 599 dimensions: (28, 28)
# Image 600 dimensions: (28, 28)
# Image 601 dimensions: (28, 28)
# Image 602 dimensions: (28, 28)
# Image 603 dimensions: (28, 28)
# Image 604 dimensions: (28, 28)
# Image 605 dimensions: (28, 28)
# Image 606 dimensions: (28, 28)
# Image 607 dimensions: (28, 28)
# Image 608 dimensions: (28, 28)
# Image 609 dimensions: (28, 28)
# Image 610 dimensions: (28, 28)
# Image 611 dimensions: (28, 28)
# Image 612 dimensions: (28, 28)
# Image 613 dimensions: (28, 28)
# Image 614 dimensions: (28, 28)
# Image 615 dimensions: (28, 28)
# Image 616 dimensions: (28, 28)
# Image 617 dimensions: (28, 28)
# Image 618 dimensions: (28, 28)
# Image 619 dimensions: (28, 28)
# Image 620 dimensions: (28, 28)
# Image 621 dimensions: (28, 28)
# Image 622 dimensions: (28, 28)
# Image 623 dimensions: (28, 28)
# Image 624 dimensions: (28, 28)
# Image 625 dimensions: (28, 28)
# Image 626 dimensions: (28, 28)
# Image 627 dimensions: (28, 28)
# Image 628 dimensions: (28, 28)
# Image 629 dimensions: (28, 28)
# Image 630 dimensions: (28, 28)
# Image 631 dimensions: (28, 28)
# Image 632 dimensions: (28, 28)
# Image 633 dimensions: (28, 28)
# Image 634 dimensions: (28, 28)
# Image 635 dimensions: (28, 28)
# Image 636 dimensions: (28, 28)
# Image 637 dimensions: (28, 28)
# Image 638 dimensions: (28, 28)
# Image 639 dimensions: (28, 28)
# Image 640 dimensions: (28, 28)
# Image 641 dimensions: (28, 28)
# Image 642 dimensions: (28, 28)
# Image 643 dimensions: (28, 28)
# Image 644 dimensions: (28, 28)
# Image 645 dimensions: (28, 28)
# Image 646 dimensions: (28, 28)
# Image 647 dimensions: (28, 28)
# Image 648 dimensions: (28, 28)
# Image 649 dimensions: (28, 28)
# Image 650 dimensions: (28, 28)
# Image 651 dimensions: (28, 28)
# Image 652 dimensions: (28, 28)
# Image 653 dimensions: (28, 28)
# Image 654 dimensions: (28, 28)
# Image 655 dimensions: (28, 28)
# Image 656 dimensions: (28, 28)
# Image 657 dimensions: (28, 28)
# Image 658 dimensions: (28, 28)
# Image 659 dimensions: (28, 28)
# Image 660 dimensions: (28, 28)
# Image 661 dimensions: (28, 28)
# Image 662 dimensions: (28, 28)
# Image 663 dimensions: (28, 28)
# Image 664 dimensions: (28, 28)
# Image 665 dimensions: (28, 28)
# Image 666 dimensions: (28, 28)
# Image 667 dimensions: (28, 28)
# Image 668 dimensions: (28, 28)
# Image 669 dimensions: (28, 28)
# Image 670 dimensions: (28, 28)
# Image 671 dimensions: (28, 28)
# Image 672 dimensions: (28, 28)
# Image 673 dimensions: (28, 28)
# Image 674 dimensions: (28, 28)
# Image 675 dimensions: (28, 28)
# Image 676 dimensions: (28, 28)
# Image 677 dimensions: (28, 28)
# Image 678 dimensions: (28, 28)
# Image 679 dimensions: (28, 28)
# Image 680 dimensions: (28, 28)
# Image 681 dimensions: (28, 28)
# Image 682 dimensions: (28, 28)
# Image 683 dimensions: (28, 28)
# Image 684 dimensions: (28, 28)
# Image 685 dimensions: (28, 28)
# Image 686 dimensions: (28, 28)
# Image 687 dimensions: (28, 28)
# Image 688 dimensions: (28, 28)
# Image 689 dimensions: (28, 28)
# Image 690 dimensions: (28, 28)
# Image 691 dimensions: (28, 28)
# Image 692 dimensions: (28, 28)
# Image 693 dimensions: (28, 28)
# Image 694 dimensions: (28, 28)
# Image 695 dimensions: (28, 28)
# Image 696 dimensions: (28, 28)
# Image 697 dimensions: (28, 28)
# Image 698 dimensions: (28, 28)
# Image 699 dimensions: (28, 28)
# Image 700 dimensions: (28, 28)
# Image 701 dimensions: (28, 28)
# Image 702 dimensions: (28, 28)
# Image 703 dimensions: (28, 28)
# Image 704 dimensions: (28, 28)
# Image 705 dimensions: (28, 28)
# Image 706 dimensions: (28, 28)
# Image 707 dimensions: (28, 28)
# Image 708 dimensions: (28, 28)
# Image 709 dimensions: (28, 28)
# Image 710 dimensions: (28, 28)
# Image 711 dimensions: (28, 28)
# Image 712 dimensions: (28, 28)
# Image 713 dimensions: (28, 28)
# Image 714 dimensions: (28, 28)
# Image 715 dimensions: (28, 28)
# Image 716 dimensions: (28, 28)
# Image 717 dimensions: (28, 28)
# Image 718 dimensions: (28, 28)
# Image 719 dimensions: (28, 28)
# Image 720 dimensions: (28, 28)
# Image 721 dimensions: (28, 28)
# Image 722 dimensions: (28, 28)
# Image 723 dimensions: (28, 28)
# Image 724 dimensions: (28, 28)
# Image 725 dimensions: (28, 28)
# Image 726 dimensions: (28, 28)
# Image 727 dimensions: (28, 28)
# Image 728 dimensions: (28, 28)
# Image 729 dimensions: (28, 28)
# Image 730 dimensions: (28, 28)
# Image 731 dimensions: (28, 28)
# Image 732 dimensions: (28, 28)
# Image 733 dimensions: (28, 28)
# Image 734 dimensions: (28, 28)
# Image 735 dimensions: (28, 28)
# Image 736 dimensions: (28, 28)
# Image 737 dimensions: (28, 28)
# Image 738 dimensions: (28, 28)
# Image 739 dimensions: (28, 28)
# Image 740 dimensions: (28, 28)
# Image 741 dimensions: (28, 28)
# Image 742 dimensions: (28, 28)
# Image 743 dimensions: (28, 28)
# Image 744 dimensions: (28, 28)
# Image 745 dimensions: (28, 28)
# Image 746 dimensions: (28, 28)
# Image 747 dimensions: (28, 28)
# Image 748 dimensions: (28, 28)
# Image 749 dimensions: (28, 28)
# Image 750 dimensions: (28, 28)
# Image 751 dimensions: (28, 28)
# Image 752 dimensions: (28, 28)
# Image 753 dimensions: (28, 28)
# Image 754 dimensions: (28, 28)
# Image 755 dimensions: (28, 28)
# Image 756 dimensions: (28, 28)
# Image 757 dimensions: (28, 28)
# Image 758 dimensions: (28, 28)
# Image 759 dimensions: (28, 28)
# Image 760 dimensions: (28, 28)
# Image 761 dimensions: (28, 28)
# Image 762 dimensions: (28, 28)
# Image 763 dimensions: (28, 28)
# Image 764 dimensions: (28, 28)
# Image 765 dimensions: (28, 28)
# Image 766 dimensions: (28, 28)
# Image 767 dimensions: (28, 28)
# Image 768 dimensions: (28, 28)
# Image 769 dimensions: (28, 28)
# Image 770 dimensions: (28, 28)
# Image 771 dimensions: (28, 28)
# Image 772 dimensions: (28, 28)
# Image 773 dimensions: (28, 28)
# Image 774 dimensions: (28, 28)
# Image 775 dimensions: (28, 28)
# Image 776 dimensions: (28, 28)
# Image 777 dimensions: (28, 28)
# Image 778 dimensions: (28, 28)
# Image 779 dimensions: (28, 28)
# Image 780 dimensions: (28, 28)
# Image 781 dimensions: (28, 28)
# Image 782 dimensions: (28, 28)
# Image 783 dimensions: (28, 28)
# Image 784 dimensions: (28, 28)
# Image 785 dimensions: (28, 28)
# Image 786 dimensions: (28, 28)
# Image 787 dimensions: (28, 28)
# Image 788 dimensions: (28, 28)
# Image 789 dimensions: (28, 28)
# Image 790 dimensions: (28, 28)
# Image 791 dimensions: (28, 28)
# Image 792 dimensions: (28, 28)
# Image 793 dimensions: (28, 28)
# Image 794 dimensions: (28, 28)
# Image 795 dimensions: (28, 28)
# Image 796 dimensions: (28, 28)
# Image 797 dimensions: (28, 28)
# Image 798 dimensions: (28, 28)
# Image 799 dimensions: (28, 28)
# Image 800 dimensions: (28, 28)
# Image 801 dimensions: (28, 28)
# Image 802 dimensions: (28, 28)
# Image 803 dimensions: (28, 28)
# Image 804 dimensions: (28, 28)
# Image 805 dimensions: (28, 28)
# Image 806 dimensions: (28, 28)
# Image 807 dimensions: (28, 28)
# Image 808 dimensions: (28, 28)
# Image 809 dimensions: (28, 28)
# Image 810 dimensions: (28, 28)
# Image 811 dimensions: (28, 28)
# Image 812 dimensions: (28, 28)
# Image 813 dimensions: (28, 28)
# Image 814 dimensions: (28, 28)
# Image 815 dimensions: (28, 28)
# Image 816 dimensions: (28, 28)
# Image 817 dimensions: (28, 28)
# Image 818 dimensions: (28, 28)
# Image 819 dimensions: (28, 28)
# Image 820 dimensions: (28, 28)
# Image 821 dimensions: (28, 28)
# Image 822 dimensions: (28, 28)
# Image 823 dimensions: (28, 28)
# Image 824 dimensions: (28, 28)
# Image 825 dimensions: (28, 28)
# Image 826 dimensions: (28, 28)
# Image 827 dimensions: (28, 28)
# Image 828 dimensions: (28, 28)
# Image 829 dimensions: (28, 28)
# Image 830 dimensions: (28, 28)
# Image 831 dimensions: (28, 28)
# Image 832 dimensions: (28, 28)
# Image 833 dimensions: (28, 28)
# Image 834 dimensions: (28, 28)
# Image 835 dimensions: (28, 28)
# Image 836 dimensions: (28, 28)
# Image 837 dimensions: (28, 28)
# Image 838 dimensions: (28, 28)
# Image 839 dimensions: (28, 28)
# Image 840 dimensions: (28, 28)
# Image 841 dimensions: (28, 28)
# Image 842 dimensions: (28, 28)
# Image 843 dimensions: (28, 28)
# Image 844 dimensions: (28, 28)
# Image 845 dimensions: (28, 28)
# Image 846 dimensions: (28, 28)
# Image 847 dimensions: (28, 28)
# Image 848 dimensions: (28, 28)
# Image 849 dimensions: (28, 28)
# Image 850 dimensions: (28, 28)
# Image 851 dimensions: (28, 28)
# Image 852 dimensions: (28, 28)
# Image 853 dimensions: (28, 28)
# Image 854 dimensions: (28, 28)
# Image 855 dimensions: (28, 28)
# Image 856 dimensions: (28, 28)
# Image 857 dimensions: (28, 28)
# Image 858 dimensions: (28, 28)
# Image 859 dimensions: (28, 28)
# Image 860 dimensions: (28, 28)
# Image 861 dimensions: (28, 28)
# Image 862 dimensions: (28, 28)
# Image 863 dimensions: (28, 28)
# Image 864 dimensions: (28, 28)
# Image 865 dimensions: (28, 28)
# Image 866 dimensions: (28, 28)
# Image 867 dimensions: (28, 28)
# Image 868 dimensions: (28, 28)
# Image 869 dimensions: (28, 28)
# Image 870 dimensions: (28, 28)
# Image 871 dimensions: (28, 28)
# Image 872 dimensions: (28, 28)
# Image 873 dimensions: (28, 28)
# Image 874 dimensions: (28, 28)
# Image 875 dimensions: (28, 28)
# Image 876 dimensions: (28, 28)
# Image 877 dimensions: (28, 28)
# Image 878 dimensions: (28, 28)
# Image 879 dimensions: (28, 28)
# Image 880 dimensions: (28, 28)
# Image 881 dimensions: (28, 28)
# Image 882 dimensions: (28, 28)
# Image 883 dimensions: (28, 28)
# Image 884 dimensions: (28, 28)
# Image 885 dimensions: (28, 28)
# Image 886 dimensions: (28, 28)
# Image 887 dimensions: (28, 28)
# Image 888 dimensions: (28, 28)
# Image 889 dimensions: (28, 28)
# Image 890 dimensions: (28, 28)
# Image 891 dimensions: (28, 28)
# Image 892 dimensions: (28, 28)
# Image 893 dimensions: (28, 28)
# Image 894 dimensions: (28, 28)
# Image 895 dimensions: (28, 28)
# Image 896 dimensions: (28, 28)
# Image 897 dimensions: (28, 28)
# Image 898 dimensions: (28, 28)
# Image 899 dimensions: (28, 28)
# Image 900 dimensions: (28, 28)
# Image 901 dimensions: (28, 28)
# Image 902 dimensions: (28, 28)
# Image 903 dimensions: (28, 28)
# Image 904 dimensions: (28, 28)
# Image 905 dimensions: (28, 28)
# Image 906 dimensions: (28, 28)
# Image 907 dimensions: (28, 28)
# Image 908 dimensions: (28, 28)
# Image 909 dimensions: (28, 28)
# Image 910 dimensions: (28, 28)
# Image 911 dimensions: (28, 28)
# Image 912 dimensions: (28, 28)
# Image 913 dimensions: (28, 28)
# Image 914 dimensions: (28, 28)
# Image 915 dimensions: (28, 28)
# Image 916 dimensions: (28, 28)
# Image 917 dimensions: (28, 28)
# Image 918 dimensions: (28, 28)
# Image 919 dimensions: (28, 28)
# Image 920 dimensions: (28, 28)
# Image 921 dimensions: (28, 28)
# Image 922 dimensions: (28, 28)
# Image 923 dimensions: (28, 28)
# Image 924 dimensions: (28, 28)
# Image 925 dimensions: (28, 28)
# Image 926 dimensions: (28, 28)
# Image 927 dimensions: (28, 28)
# Image 928 dimensions: (28, 28)
# Image 929 dimensions: (28, 28)
# Image 930 dimensions: (28, 28)
# Image 931 dimensions: (28, 28)
# Image 932 dimensions: (28, 28)
# Image 933 dimensions: (28, 28)
# Image 934 dimensions: (28, 28)
# Image 935 dimensions: (28, 28)
# Image 936 dimensions: (28, 28)
# Image 937 dimensions: (28, 28)
# Image 938 dimensions: (28, 28)
# Image 939 dimensions: (28, 28)
# Image 940 dimensions: (28, 28)
# Image 941 dimensions: (28, 28)
# Image 942 dimensions: (28, 28)
# Image 943 dimensions: (28, 28)
# Image 944 dimensions: (28, 28)
# Image 945 dimensions: (28, 28)
# Image 946 dimensions: (28, 28)
# Image 947 dimensions: (28, 28)
# Image 948 dimensions: (28, 28)
# Image 949 dimensions: (28, 28)
# Image 950 dimensions: (28, 28)
# Image 951 dimensions: (28, 28)
# Image 952 dimensions: (28, 28)
# Image 953 dimensions: (28, 28)
# Image 954 dimensions: (28, 28)
# Image 955 dimensions: (28, 28)
# Image 956 dimensions: (28, 28)
# Image 957 dimensions: (28, 28)
# Image 958 dimensions: (28, 28)
# Image 959 dimensions: (28, 28)
# Image 960 dimensions: (28, 28)
# Image 961 dimensions: (28, 28)
# Image 962 dimensions: (28, 28)
# Image 963 dimensions: (28, 28)
# Image 964 dimensions: (28, 28)
# Image 965 dimensions: (28, 28)
# Image 966 dimensions: (28, 28)
# Image 967 dimensions: (28, 28)
# Image 968 dimensions: (28, 28)
# Image 969 dimensions: (28, 28)
# Image 970 dimensions: (28, 28)
# Image 971 dimensions: (28, 28)
# Image 972 dimensions: (28, 28)
# Image 973 dimensions: (28, 28)
# Image 974 dimensions: (28, 28)
# Image 975 dimensions: (28, 28)
# Image 976 dimensions: (28, 28)
# Image 977 dimensions: (28, 28)
# Image 978 dimensions: (28, 28)
# Image 979 dimensions: (28, 28)
# Image 980 dimensions: (28, 28)
# Image 981 dimensions: (28, 28)
# Image 982 dimensions: (28, 28)
# Image 983 dimensions: (28, 28)
# Image 984 dimensions: (28, 28)
# Image 985 dimensions: (28, 28)
# Image 986 dimensions: (28, 28)
# Image 987 dimensions: (28, 28)
# Image 988 dimensions: (28, 28)
# Image 989 dimensions: (28, 28)
# Image 990 dimensions: (28, 28)
# Image 991 dimensions: (28, 28)
# Image 992 dimensions: (28, 28)
# Image 993 dimensions: (28, 28)
# Image 994 dimensions: (28, 28)
# Image 995 dimensions: (28, 28)
# Image 996 dimensions: (28, 28)
# Image 997 dimensions: (28, 28)
# Image 998 dimensions: (28, 28)
# Image 999 dimensions: (28, 28)
# Image 1000 dimensions: (28, 28)
# Image 1001 dimensions: (28, 28)
# Image 1002 dimensions: (28, 28)
# Image 1003 dimensions: (28, 28)
# Image 1004 dimensions: (28, 28)
# Image 1005 dimensions: (28, 28)
# Image 1006 dimensions: (28, 28)
# Image 1007 dimensions: (28, 28)
# Image 1008 dimensions: (28, 28)
# Image 1009 dimensions: (28, 28)
# Image 1010 dimensions: (28, 28)
# Image 1011 dimensions: (28, 28)
# Image 1012 dimensions: (28, 28)
# Image 1013 dimensions: (28, 28)
# Image 1014 dimensions: (28, 28)
# Image 1015 dimensions: (28, 28)
# Image 1016 dimensions: (28, 28)
# Image 1017 dimensions: (28, 28)
# Image 1018 dimensions: (28, 28)
# Image 1019 dimensions: (28, 28)
# Image 1020 dimensions: (28, 28)
# Image 1021 dimensions: (28, 28)
# Image 1022 dimensions: (28, 28)
# Image 1023 dimensions: (28, 28)
# Image 1024 dimensions: (28, 28)
# Image 1025 dimensions: (28, 28)
# Image 1026 dimensions: (28, 28)
# Image 1027 dimensions: (28, 28)
# Image 1028 dimensions: (28, 28)
# Image 1029 dimensions: (28, 28)
# Image 1030 dimensions: (28, 28)
# Image 1031 dimensions: (28, 28)
# Image 1032 dimensions: (28, 28)
# Image 1033 dimensions: (28, 28)
# Image 1034 dimensions: (28, 28)
# Image 1035 dimensions: (28, 28)
# Image 1036 dimensions: (28, 28)
# Image 1037 dimensions: (28, 28)
# Image 1038 dimensions: (28, 28)
# Image 1039 dimensions: (28, 28)
# Image 1040 dimensions: (28, 28)
# Image 1041 dimensions: (28, 28)
# Image 1042 dimensions: (28, 28)
# Image 1043 dimensions: (28, 28)
# Image 1044 dimensions: (28, 28)
# Image 1045 dimensions: (28, 28)
# Image 1046 dimensions: (28, 28)
# Image 1047 dimensions: (28, 28)
# Image 1048 dimensions: (28, 28)
# Image 1049 dimensions: (28, 28)
# Image 1050 dimensions: (28, 28)
# Image 1051 dimensions: (28, 28)
# Image 1052 dimensions: (28, 28)
# Image 1053 dimensions: (28, 28)
# Image 1054 dimensions: (28, 28)
# Image 1055 dimensions: (28, 28)
# Image 1056 dimensions: (28, 28)
# Image 1057 dimensions: (28, 28)
# Image 1058 dimensions: (28, 28)
# Image 1059 dimensions: (28, 28)
# Image 1060 dimensions: (28, 28)
# Image 1061 dimensions: (28, 28)
# Image 1062 dimensions: (28, 28)
# Image 1063 dimensions: (28, 28)
# Image 1064 dimensions: (28, 28)
# Image 1065 dimensions: (28, 28)
# Image 1066 dimensions: (28, 28)
# Image 1067 dimensions: (28, 28)
# Image 1068 dimensions: (28, 28)
# Image 1069 dimensions: (28, 28)
# Image 1070 dimensions: (28, 28)
# Image 1071 dimensions: (28, 28)
# Image 1072 dimensions: (28, 28)
# Image 1073 dimensions: (28, 28)
# Image 1074 dimensions: (28, 28)
# Image 1075 dimensions: (28, 28)
# Image 1076 dimensions: (28, 28)
# Image 1077 dimensions: (28, 28)
# Image 1078 dimensions: (28, 28)
# Image 1079 dimensions: (28, 28)
# Image 1080 dimensions: (28, 28)
# Image 1081 dimensions: (28, 28)
# Image 1082 dimensions: (28, 28)
# Image 1083 dimensions: (28, 28)
# Image 1084 dimensions: (28, 28)
# Image 1085 dimensions: (28, 28)
# Image 1086 dimensions: (28, 28)
# Image 1087 dimensions: (28, 28)
# Image 1088 dimensions: (28, 28)
# Image 1089 dimensions: (28, 28)
# Image 1090 dimensions: (28, 28)
# Image 1091 dimensions: (28, 28)
# Image 1092 dimensions: (28, 28)
# Image 1093 dimensions: (28, 28)
# Image 1094 dimensions: (28, 28)
# Image 1095 dimensions: (28, 28)
# Image 1096 dimensions: (28, 28)
# Image 1097 dimensions: (28, 28)
# Image 1098 dimensions: (28, 28)
# Image 1099 dimensions: (28, 28)
# Image 1100 dimensions: (28, 28)
# Image 1101 dimensions: (28, 28)
# Image 1102 dimensions: (28, 28)
# Image 1103 dimensions: (28, 28)
# Image 1104 dimensions: (28, 28)
# Image 1105 dimensions: (28, 28)
# Image 1106 dimensions: (28, 28)
# Image 1107 dimensions: (28, 28)
# Image 1108 dimensions: (28, 28)
# Image 1109 dimensions: (28, 28)
# Image 1110 dimensions: (28, 28)
# Image 1111 dimensions: (28, 28)
# Image 1112 dimensions: (28, 28)
# Image 1113 dimensions: (28, 28)
# Image 1114 dimensions: (28, 28)
# Image 1115 dimensions: (28, 28)
# Image 1116 dimensions: (28, 28)
# Image 1117 dimensions: (28, 28)
# Image 1118 dimensions: (28, 28)
# Image 1119 dimensions: (28, 28)
# Image 1120 dimensions: (28, 28)
# Image 1121 dimensions: (28, 28)
# Image 1122 dimensions: (28, 28)
# Image 1123 dimensions: (28, 28)
# Image 1124 dimensions: (28, 28)
# Image 1125 dimensions: (28, 28)
# Image 1126 dimensions: (28, 28)
# Image 1127 dimensions: (28, 28)
# Image 1128 dimensions: (28, 28)
# Image 1129 dimensions: (28, 28)
# Image 1130 dimensions: (28, 28)
# Image 1131 dimensions: (28, 28)
# Image 1132 dimensions: (28, 28)
# Image 1133 dimensions: (28, 28)
# Image 1134 dimensions: (28, 28)
# Image 1135 dimensions: (28, 28)
# Image 1136 dimensions: (28, 28)
# Image 1137 dimensions: (28, 28)
# Image 1138 dimensions: (28, 28)
# Image 1139 dimensions: (28, 28)
# Image 1140 dimensions: (28, 28)
# Image 1141 dimensions: (28, 28)
# Image 1142 dimensions: (28, 28)
# Image 1143 dimensions: (28, 28)
# Image 1144 dimensions: (28, 28)
# Image 1145 dimensions: (28, 28)
# Image 1146 dimensions: (28, 28)
# Image 1147 dimensions: (28, 28)
# Image 1148 dimensions: (28, 28)
# Image 1149 dimensions: (28, 28)
# Image 1150 dimensions: (28, 28)
# Image 1151 dimensions: (28, 28)
# Image 1152 dimensions: (28, 28)
# Image 1153 dimensions: (28, 28)
# Image 1154 dimensions: (28, 28)
# Image 1155 dimensions: (28, 28)
# Image 1156 dimensions: (28, 28)
# Image 1157 dimensions: (28, 28)
# Image 1158 dimensions: (28, 28)
# Image 1159 dimensions: (28, 28)
# Image 1160 dimensions: (28, 28)
# Image 1161 dimensions: (28, 28)
# Image 1162 dimensions: (28, 28)
# Image 1163 dimensions: (28, 28)
# Image 1164 dimensions: (28, 28)
# Image 1165 dimensions: (28, 28)
# Image 1166 dimensions: (28, 28)
# Image 1167 dimensions: (28, 28)
# Image 1168 dimensions: (28, 28)
# Image 1169 dimensions: (28, 28)
# Image 1170 dimensions: (28, 28)
# Image 1171 dimensions: (28, 28)
# Image 1172 dimensions: (28, 28)
# Image 1173 dimensions: (28, 28)
# Image 1174 dimensions: (28, 28)
# Image 1175 dimensions: (28, 28)
# Image 1176 dimensions: (28, 28)
# Image 1177 dimensions: (28, 28)
# Image 1178 dimensions: (28, 28)
# Image 1179 dimensions: (28, 28)
# Image 1180 dimensions: (28, 28)
# Image 1181 dimensions: (28, 28)
# Image 1182 dimensions: (28, 28)
# Image 1183 dimensions: (28, 28)
# Image 1184 dimensions: (28, 28)
# Image 1185 dimensions: (28, 28)
# Image 1186 dimensions: (28, 28)
# Image 1187 dimensions: (28, 28)
# Image 1188 dimensions: (28, 28)
# Image 1189 dimensions: (28, 28)
# Image 1190 dimensions: (28, 28)
# Image 1191 dimensions: (28, 28)
# Image 1192 dimensions: (28, 28)
# Image 1193 dimensions: (28, 28)
# Image 1194 dimensions: (28, 28)
# Image 1195 dimensions: (28, 28)
# Image 1196 dimensions: (28, 28)
# Image 1197 dimensions: (28, 28)
# Image 1198 dimensions: (28, 28)
# Image 1199 dimensions: (28, 28)
# Image 1200 dimensions: (28, 28)
# Image 1201 dimensions: (28, 28)
# Image 1202 dimensions: (28, 28)
# Image 1203 dimensions: (28, 28)
# Image 1204 dimensions: (28, 28)
# Image 1205 dimensions: (28, 28)
# Image 1206 dimensions: (28, 28)
# Image 1207 dimensions: (28, 28)
# Image 1208 dimensions: (28, 28)
# Image 1209 dimensions: (28, 28)
# Image 1210 dimensions: (28, 28)
# Image 1211 dimensions: (28, 28)
# Image 1212 dimensions: (28, 28)
# Image 1213 dimensions: (28, 28)
# Image 1214 dimensions: (28, 28)
# Image 1215 dimensions: (28, 28)
# Image 1216 dimensions: (28, 28)
# Image 1217 dimensions: (28, 28)
# Image 1218 dimensions: (28, 28)
# Image 1219 dimensions: (28, 28)
# Image 1220 dimensions: (28, 28)
# Image 1221 dimensions: (28, 28)
# Image 1222 dimensions: (28, 28)
# Image 1223 dimensions: (28, 28)
# Image 1224 dimensions: (28, 28)
# Image 1225 dimensions: (28, 28)
# Image 1226 dimensions: (28, 28)
# Image 1227 dimensions: (28, 28)
# Image 1228 dimensions: (28, 28)
# Image 1229 dimensions: (28, 28)
# Image 1230 dimensions: (28, 28)
# Image 1231 dimensions: (28, 28)
# Image 1232 dimensions: (28, 28)
# Image 1233 dimensions: (28, 28)
# Image 1234 dimensions: (28, 28)
# Image 1235 dimensions: (28, 28)
# Image 1236 dimensions: (28, 28)
# Image 1237 dimensions: (28, 28)
# Image 1238 dimensions: (28, 28)
# Image 1239 dimensions: (28, 28)
# Image 1240 dimensions: (28, 28)
# Image 1241 dimensions: (28, 28)
# Image 1242 dimensions: (28, 28)
# Image 1243 dimensions: (28, 28)
# Image 1244 dimensions: (28, 28)
# Image 1245 dimensions: (28, 28)
# Image 1246 dimensions: (28, 28)
# Image 1247 dimensions: (28, 28)
# Image 1248 dimensions: (28, 28)
# Image 1249 dimensions: (28, 28)
# Image 1250 dimensions: (28, 28)
# Image 1251 dimensions: (28, 28)
# Image 1252 dimensions: (28, 28)
# Image 1253 dimensions: (28, 28)
# Image 1254 dimensions: (28, 28)
# Image 1255 dimensions: (28, 28)
# Image 1256 dimensions: (28, 28)
# Image 1257 dimensions: (28, 28)
# Image 1258 dimensions: (28, 28)
# Image 1259 dimensions: (28, 28)
# Image 1260 dimensions: (28, 28)
# Image 1261 dimensions: (28, 28)
# Image 1262 dimensions: (28, 28)
# Image 1263 dimensions: (28, 28)
# Image 1264 dimensions: (28, 28)
# Image 1265 dimensions: (28, 28)
# Image 1266 dimensions: (28, 28)
# Image 1267 dimensions: (28, 28)
# Image 1268 dimensions: (28, 28)
# Image 1269 dimensions: (28, 28)
# Image 1270 dimensions: (28, 28)
# Image 1271 dimensions: (28, 28)
# Image 1272 dimensions: (28, 28)
# Image 1273 dimensions: (28, 28)
# Image 1274 dimensions: (28, 28)
# Image 1275 dimensions: (28, 28)
# Image 1276 dimensions: (28, 28)
# Image 1277 dimensions: (28, 28)
# Image 1278 dimensions: (28, 28)
# Image 1279 dimensions: (28, 28)
# Image 1280 dimensions: (28, 28)
# Image 1281 dimensions: (28, 28)
# Image 1282 dimensions: (28, 28)
# Image 1283 dimensions: (28, 28)
# Image 1284 dimensions: (28, 28)
# Image 1285 dimensions: (28, 28)
# Image 1286 dimensions: (28, 28)
# Image 1287 dimensions: (28, 28)
# Image 1288 dimensions: (28, 28)
# Image 1289 dimensions: (28, 28)
# Image 1290 dimensions: (28, 28)
# Image 1291 dimensions: (28, 28)
# Image 1292 dimensions: (28, 28)
# Image 1293 dimensions: (28, 28)
# Image 1294 dimensions: (28, 28)
# Image 1295 dimensions: (28, 28)
# Image 1296 dimensions: (28, 28)
# Image 1297 dimensions: (28, 28)
# Image 1298 dimensions: (28, 28)
# Image 1299 dimensions: (28, 28)
# Image 1300 dimensions: (28, 28)
# Image 1301 dimensions: (28, 28)
# Image 1302 dimensions: (28, 28)
# Image 1303 dimensions: (28, 28)
# Image 1304 dimensions: (28, 28)
# Image 1305 dimensions: (28, 28)
# Image 1306 dimensions: (28, 28)
# Image 1307 dimensions: (28, 28)
# Image 1308 dimensions: (28, 28)
# Image 1309 dimensions: (28, 28)
# Image 1310 dimensions: (28, 28)
# Image 1311 dimensions: (28, 28)
# Image 1312 dimensions: (28, 28)
# Image 1313 dimensions: (28, 28)
# Image 1314 dimensions: (28, 28)
# Image 1315 dimensions: (28, 28)
# Image 1316 dimensions: (28, 28)
# Image 1317 dimensions: (28, 28)
# Image 1318 dimensions: (28, 28)
# Image 1319 dimensions: (28, 28)
# Image 1320 dimensions: (28, 28)
# Image 1321 dimensions: (28, 28)
# Image 1322 dimensions: (28, 28)
# Image 1323 dimensions: (28, 28)
# Image 1324 dimensions: (28, 28)
# Image 1325 dimensions: (28, 28)
# Image 1326 dimensions: (28, 28)
# Image 1327 dimensions: (28, 28)
# Image 1328 dimensions: (28, 28)
# Image 1329 dimensions: (28, 28)
# Image 1330 dimensions: (28, 28)
# Image 1331 dimensions: (28, 28)
# Image 1332 dimensions: (28, 28)
# Image 1333 dimensions: (28, 28)
# Image 1334 dimensions: (28, 28)
# Image 1335 dimensions: (28, 28)
# Image 1336 dimensions: (28, 28)
# Image 1337 dimensions: (28, 28)
# Image 1338 dimensions: (28, 28)
# Image 1339 dimensions: (28, 28)
# Image 1340 dimensions: (28, 28)
# Image 1341 dimensions: (28, 28)
# Image 1342 dimensions: (28, 28)
# Image 1343 dimensions: (28, 28)
# Image 1344 dimensions: (28, 28)
# Image 1345 dimensions: (28, 28)
# Image 1346 dimensions: (28, 28)
# Image 1347 dimensions: (28, 28)
# Image 1348 dimensions: (28, 28)
# Image 1349 dimensions: (28, 28)
# Image 1350 dimensions: (28, 28)
# Image 1351 dimensions: (28, 28)
# Image 1352 dimensions: (28, 28)
# Image 1353 dimensions: (28, 28)
# Image 1354 dimensions: (28, 28)
# Image 1355 dimensions: (28, 28)
# Image 1356 dimensions: (28, 28)
# Image 1357 dimensions: (28, 28)
# Image 1358 dimensions: (28, 28)
# Image 1359 dimensions: (28, 28)
# Image 1360 dimensions: (28, 28)
# Image 1361 dimensions: (28, 28)
# Image 1362 dimensions: (28, 28)
# Image 1363 dimensions: (28, 28)
# Image 1364 dimensions: (28, 28)
# Image 1365 dimensions: (28, 28)
# Image 1366 dimensions: (28, 28)
# Image 1367 dimensions: (28, 28)
# Image 1368 dimensions: (28, 28)
# Image 1369 dimensions: (28, 28)
# Image 1370 dimensions: (28, 28)
# Image 1371 dimensions: (28, 28)
# Image 1372 dimensions: (28, 28)
# Image 1373 dimensions: (28, 28)
# Image 1374 dimensions: (28, 28)
# Image 1375 dimensions: (28, 28)
# Image 1376 dimensions: (28, 28)
# Image 1377 dimensions: (28, 28)
# Image 1378 dimensions: (28, 28)
# Image 1379 dimensions: (28, 28)
# Image 1380 dimensions: (28, 28)
# Image 1381 dimensions: (28, 28)
# Image 1382 dimensions: (28, 28)
# Image 1383 dimensions: (28, 28)
# Image 1384 dimensions: (28, 28)
# Image 1385 dimensions: (28, 28)
# Image 1386 dimensions: (28, 28)
# Image 1387 dimensions: (28, 28)
# Image 1388 dimensions: (28, 28)
# Image 1389 dimensions: (28, 28)
# Image 1390 dimensions: (28, 28)
# Image 1391 dimensions: (28, 28)
# Image 1392 dimensions: (28, 28)
# Image 1393 dimensions: (28, 28)
# Image 1394 dimensions: (28, 28)
# Image 1395 dimensions: (28, 28)
# Image 1396 dimensions: (28, 28)
# Image 1397 dimensions: (28, 28)
# Image 1398 dimensions: (28, 28)
# Image 1399 dimensions: (28, 28)
# Image 1400 dimensions: (28, 28)
# Image 1401 dimensions: (28, 28)
# Image 1402 dimensions: (28, 28)
# Image 1403 dimensions: (28, 28)
# Image 1404 dimensions: (28, 28)
# Image 1405 dimensions: (28, 28)
# Image 1406 dimensions: (28, 28)
# Image 1407 dimensions: (28, 28)
# Image 1408 dimensions: (28, 28)
# Image 1409 dimensions: (28, 28)
# Image 1410 dimensions: (28, 28)
# Image 1411 dimensions: (28, 28)
# Image 1412 dimensions: (28, 28)
# Image 1413 dimensions: (28, 28)
# Image 1414 dimensions: (28, 28)
# Image 1415 dimensions: (28, 28)
# Image 1416 dimensions: (28, 28)
# Image 1417 dimensions: (28, 28)
# Image 1418 dimensions: (28, 28)
# Image 1419 dimensions: (28, 28)
# Image 1420 dimensions: (28, 28)
# Image 1421 dimensions: (28, 28)
# Image 1422 dimensions: (28, 28)
# Image 1423 dimensions: (28, 28)
# Image 1424 dimensions: (28, 28)
# Image 1425 dimensions: (28, 28)
# Image 1426 dimensions: (28, 28)
# Image 1427 dimensions: (28, 28)
# Image 1428 dimensions: (28, 28)
# Image 1429 dimensions: (28, 28)
# Image 1430 dimensions: (28, 28)
# Image 1431 dimensions: (28, 28)
# Image 1432 dimensions: (28, 28)
# Image 1433 dimensions: (28, 28)
# Image 1434 dimensions: (28, 28)
# Image 1435 dimensions: (28, 28)
# Image 1436 dimensions: (28, 28)
# Image 1437 dimensions: (28, 28)
# Image 1438 dimensions: (28, 28)
# Image 1439 dimensions: (28, 28)
# Image 1440 dimensions: (28, 28)
# Image 1441 dimensions: (28, 28)
# Image 1442 dimensions: (28, 28)
# Image 1443 dimensions: (28, 28)
# Image 1444 dimensions: (28, 28)
# Image 1445 dimensions: (28, 28)
# Image 1446 dimensions: (28, 28)
# Image 1447 dimensions: (28, 28)
# Image 1448 dimensions: (28, 28)
# Image 1449 dimensions: (28, 28)
# Image 1450 dimensions: (28, 28)
# Image 1451 dimensions: (28, 28)
# Image 1452 dimensions: (28, 28)
# Image 1453 dimensions: (28, 28)
# Image 1454 dimensions: (28, 28)
# Image 1455 dimensions: (28, 28)
# Image 1456 dimensions: (28, 28)
# Image 1457 dimensions: (28, 28)
# Image 1458 dimensions: (28, 28)
# Image 1459 dimensions: (28, 28)
# Image 1460 dimensions: (28, 28)
# Image 1461 dimensions: (28, 28)
# Image 1462 dimensions: (28, 28)
# Image 1463 dimensions: (28, 28)
# Image 1464 dimensions: (28, 28)
# Image 1465 dimensions: (28, 28)
# Image 1466 dimensions: (28, 28)
# Image 1467 dimensions: (28, 28)
# Image 1468 dimensions: (28, 28)
# Image 1469 dimensions: (28, 28)
# Image 1470 dimensions: (28, 28)
# Image 1471 dimensions: (28, 28)
# Image 1472 dimensions: (28, 28)
# Image 1473 dimensions: (28, 28)
# Image 1474 dimensions: (28, 28)
# Image 1475 dimensions: (28, 28)
# Image 1476 dimensions: (28, 28)
# Image 1477 dimensions: (28, 28)
# Image 1478 dimensions: (28, 28)
# Image 1479 dimensions: (28, 28)
# Image 1480 dimensions: (28, 28)
# Image 1481 dimensions: (28, 28)
# Image 1482 dimensions: (28, 28)
# Image 1483 dimensions: (28, 28)
# Image 1484 dimensions: (28, 28)
# Image 1485 dimensions: (28, 28)
# Image 1486 dimensions: (28, 28)
# Image 1487 dimensions: (28, 28)
# Image 1488 dimensions: (28, 28)
# Image 1489 dimensions: (28, 28)
# Image 1490 dimensions: (28, 28)
# Image 1491 dimensions: (28, 28)
# Image 1492 dimensions: (28, 28)
# Image 1493 dimensions: (28, 28)
# Image 1494 dimensions: (28, 28)
# Image 1495 dimensions: (28, 28)
# Image 1496 dimensions: (28, 28)
# Image 1497 dimensions: (28, 28)
# Image 1498 dimensions: (28, 28)
# Image 1499 dimensions: (28, 28)
# Image 1500 dimensions: (28, 28)
# Image 1501 dimensions: (28, 28)
# Image 1502 dimensions: (28, 28)
# Image 1503 dimensions: (28, 28)
# Image 1504 dimensions: (28, 28)
# Image 1505 dimensions: (28, 28)
# Image 1506 dimensions: (28, 28)
# Image 1507 dimensions: (28, 28)
# Image 1508 dimensions: (28, 28)
# Image 1509 dimensions: (28, 28)
# Image 1510 dimensions: (28, 28)
# Image 1511 dimensions: (28, 28)
# Image 1512 dimensions: (28, 28)
# Image 1513 dimensions: (28, 28)
# Image 1514 dimensions: (28, 28)
# Image 1515 dimensions: (28, 28)
# Image 1516 dimensions: (28, 28)
# Image 1517 dimensions: (28, 28)
# Image 1518 dimensions: (28, 28)
# Image 1519 dimensions: (28, 28)
# Image 1520 dimensions: (28, 28)
# Image 1521 dimensions: (28, 28)
# Image 1522 dimensions: (28, 28)
# Image 1523 dimensions: (28, 28)
# Image 1524 dimensions: (28, 28)
# Image 1525 dimensions: (28, 28)
# Image 1526 dimensions: (28, 28)
# Image 1527 dimensions: (28, 28)
# Image 1528 dimensions: (28, 28)
# Image 1529 dimensions: (28, 28)
# Image 1530 dimensions: (28, 28)
# Image 1531 dimensions: (28, 28)
# Image 1532 dimensions: (28, 28)
# Image 1533 dimensions: (28, 28)
# Image 1534 dimensions: (28, 28)
# ...
# Image 59517 dimensions: (28, 28)
# Image 59518 dimensions: (28, 28)
# Image 59519 dimensions: (28, 28)
# Image 59520 dimensions: (28, 28)
# Image 59521 dimensions: (28, 28)
# Image 59522 dimensions: (28, 28)
# Image 59523 dimensions: (28, 28)
# Image 59524 dimensions: (28, 28)
# Image 59525 dimensions: (28, 28)
# Image 59526 dimensions: (28, 28)
# Image 59527 dimensions: (28, 28)
# Image 59528 dimensions: (28, 28)
# Image 59529 dimensions: (28, 28)
# Image 59530 dimensions: (28, 28)
# Image 59531 dimensions: (28, 28)
# Image 59532 dimensions: (28, 28)
# Image 59533 dimensions: (28, 28)
# Image 59534 dimensions: (28, 28)
# Image 59535 dimensions: (28, 28)
# Image 59536 dimensions: (28, 28)
# Image 59537 dimensions: (28, 28)
# Image 59538 dimensions: (28, 28)
# Image 59539 dimensions: (28, 28)
# Image 59540 dimensions: (28, 28)
# Image 59541 dimensions: (28, 28)
# Image 59542 dimensions: (28, 28)
# Image 59543 dimensions: (28, 28)
# Image 59544 dimensions: (28, 28)
# Image 59545 dimensions: (28, 28)
# Image 59546 dimensions: (28, 28)
# Image 59547 dimensions: (28, 28)
# Image 59548 dimensions: (28, 28)
# Image 59549 dimensions: (28, 28)
# Image 59550 dimensions: (28, 28)
# Image 59551 dimensions: (28, 28)
# Image 59552 dimensions: (28, 28)
# Image 59553 dimensions: (28, 28)
# Image 59554 dimensions: (28, 28)
# Image 59555 dimensions: (28, 28)
# Image 59556 dimensions: (28, 28)
# Image 59557 dimensions: (28, 28)
# Image 59558 dimensions: (28, 28)
# Image 59559 dimensions: (28, 28)
# Image 59560 dimensions: (28, 28)
# Image 59561 dimensions: (28, 28)
# Image 59562 dimensions: (28, 28)
# Image 59563 dimensions: (28, 28)
# Image 59564 dimensions: (28, 28)
# Image 59565 dimensions: (28, 28)
# Image 59566 dimensions: (28, 28)
# Image 59567 dimensions: (28, 28)
# Image 59568 dimensions: (28, 28)
# Image 59569 dimensions: (28, 28)
# Image 59570 dimensions: (28, 28)
# Image 59571 dimensions: (28, 28)
# Image 59572 dimensions: (28, 28)
# Image 59573 dimensions: (28, 28)
# Image 59574 dimensions: (28, 28)
# Image 59575 dimensions: (28, 28)
# Image 59576 dimensions: (28, 28)
# Image 59577 dimensions: (28, 28)
# Image 59578 dimensions: (28, 28)
# Image 59579 dimensions: (28, 28)
# Image 59580 dimensions: (28, 28)
# Image 59581 dimensions: (28, 28)
# Image 59582 dimensions: (28, 28)
# Image 59583 dimensions: (28, 28)
# Image 59584 dimensions: (28, 28)
# Image 59585 dimensions: (28, 28)
# Image 59586 dimensions: (28, 28)
# Image 59587 dimensions: (28, 28)
# Image 59588 dimensions: (28, 28)
# Image 59589 dimensions: (28, 28)
# Image 59590 dimensions: (28, 28)
# Image 59591 dimensions: (28, 28)
# Image 59592 dimensions: (28, 28)
# Image 59593 dimensions: (28, 28)
# Image 59594 dimensions: (28, 28)
# Image 59595 dimensions: (28, 28)
# Image 59596 dimensions: (28, 28)
# Image 59597 dimensions: (28, 28)
# Image 59598 dimensions: (28, 28)
# Image 59599 dimensions: (28, 28)
# Image 59600 dimensions: (28, 28)
# Image 59601 dimensions: (28, 28)
# Image 59602 dimensions: (28, 28)
# Image 59603 dimensions: (28, 28)
# Image 59604 dimensions: (28, 28)
# Image 59605 dimensions: (28, 28)
# Image 59606 dimensions: (28, 28)
# Image 59607 dimensions: (28, 28)
# Image 59608 dimensions: (28, 28)
# Image 59609 dimensions: (28, 28)
# Image 59610 dimensions: (28, 28)
# Image 59611 dimensions: (28, 28)
# Image 59612 dimensions: (28, 28)
# Image 59613 dimensions: (28, 28)
# Image 59614 dimensions: (28, 28)
# Image 59615 dimensions: (28, 28)
# Image 59616 dimensions: (28, 28)
# Image 59617 dimensions: (28, 28)
# Image 59618 dimensions: (28, 28)
# Image 59619 dimensions: (28, 28)
# Image 59620 dimensions: (28, 28)
# Image 59621 dimensions: (28, 28)
# Image 59622 dimensions: (28, 28)
# Image 59623 dimensions: (28, 28)
# Image 59624 dimensions: (28, 28)
# Image 59625 dimensions: (28, 28)
# Image 59626 dimensions: (28, 28)
# Image 59627 dimensions: (28, 28)
# Image 59628 dimensions: (28, 28)
# Image 59629 dimensions: (28, 28)
# Image 59630 dimensions: (28, 28)
# Image 59631 dimensions: (28, 28)
# Image 59632 dimensions: (28, 28)
# Image 59633 dimensions: (28, 28)
# Image 59634 dimensions: (28, 28)
# Image 59635 dimensions: (28, 28)
# Image 59636 dimensions: (28, 28)
# Image 59637 dimensions: (28, 28)
# Image 59638 dimensions: (28, 28)
# Image 59639 dimensions: (28, 28)
# Image 59640 dimensions: (28, 28)
# Image 59641 dimensions: (28, 28)
# Image 59642 dimensions: (28, 28)
# Image 59643 dimensions: (28, 28)
# Image 59644 dimensions: (28, 28)
# Image 59645 dimensions: (28, 28)
# Image 59646 dimensions: (28, 28)
# Image 59647 dimensions: (28, 28)
# Image 59648 dimensions: (28, 28)
# Image 59649 dimensions: (28, 28)
# Image 59650 dimensions: (28, 28)
# Image 59651 dimensions: (28, 28)
# Image 59652 dimensions: (28, 28)
# Image 59653 dimensions: (28, 28)
# Image 59654 dimensions: (28, 28)
# Image 59655 dimensions: (28, 28)
# Image 59656 dimensions: (28, 28)
# Image 59657 dimensions: (28, 28)
# Image 59658 dimensions: (28, 28)
# Image 59659 dimensions: (28, 28)
# Image 59660 dimensions: (28, 28)
# Image 59661 dimensions: (28, 28)
# Image 59662 dimensions: (28, 28)
# Image 59663 dimensions: (28, 28)
# Image 59664 dimensions: (28, 28)
# Image 59665 dimensions: (28, 28)
# Image 59666 dimensions: (28, 28)
# Image 59667 dimensions: (28, 28)
# Image 59668 dimensions: (28, 28)
# Image 59669 dimensions: (28, 28)
# Image 59670 dimensions: (28, 28)
# Image 59671 dimensions: (28, 28)
# Image 59672 dimensions: (28, 28)
# Image 59673 dimensions: (28, 28)
# Image 59674 dimensions: (28, 28)
# Image 59675 dimensions: (28, 28)
# Image 59676 dimensions: (28, 28)
# Image 59677 dimensions: (28, 28)
# Image 59678 dimensions: (28, 28)
# Image 59679 dimensions: (28, 28)
# Image 59680 dimensions: (28, 28)
# Image 59681 dimensions: (28, 28)
# Image 59682 dimensions: (28, 28)
# Image 59683 dimensions: (28, 28)
# Image 59684 dimensions: (28, 28)
# Image 59685 dimensions: (28, 28)
# Image 59686 dimensions: (28, 28)
# Image 59687 dimensions: (28, 28)
# Image 59688 dimensions: (28, 28)
# Image 59689 dimensions: (28, 28)
# Image 59690 dimensions: (28, 28)
# Image 59691 dimensions: (28, 28)
# Image 59692 dimensions: (28, 28)
# Image 59693 dimensions: (28, 28)
# Image 59694 dimensions: (28, 28)
# Image 59695 dimensions: (28, 28)
# Image 59696 dimensions: (28, 28)
# Image 59697 dimensions: (28, 28)
# Image 59698 dimensions: (28, 28)
# Image 59699 dimensions: (28, 28)
# Image 59700 dimensions: (28, 28)
# Image 59701 dimensions: (28, 28)
# Image 59702 dimensions: (28, 28)
# Image 59703 dimensions: (28, 28)
# Image 59704 dimensions: (28, 28)
# Image 59705 dimensions: (28, 28)
# Image 59706 dimensions: (28, 28)
# Image 59707 dimensions: (28, 28)
# Image 59708 dimensions: (28, 28)
# Image 59709 dimensions: (28, 28)
# Image 59710 dimensions: (28, 28)
# Image 59711 dimensions: (28, 28)
# Image 59712 dimensions: (28, 28)
# Image 59713 dimensions: (28, 28)
# Image 59714 dimensions: (28, 28)
# Image 59715 dimensions: (28, 28)
# Image 59716 dimensions: (28, 28)
# Image 59717 dimensions: (28, 28)
# Image 59718 dimensions: (28, 28)
# Image 59719 dimensions: (28, 28)
# Image 59720 dimensions: (28, 28)
# Image 59721 dimensions: (28, 28)
# Image 59722 dimensions: (28, 28)
# Image 59723 dimensions: (28, 28)
# Image 59724 dimensions: (28, 28)
# Image 59725 dimensions: (28, 28)
# Image 59726 dimensions: (28, 28)
# Image 59727 dimensions: (28, 28)
# Image 59728 dimensions: (28, 28)
# Image 59729 dimensions: (28, 28)
# Image 59730 dimensions: (28, 28)
# Image 59731 dimensions: (28, 28)
# Image 59732 dimensions: (28, 28)
# Image 59733 dimensions: (28, 28)
# Image 59734 dimensions: (28, 28)
# Image 59735 dimensions: (28, 28)
# Image 59736 dimensions: (28, 28)
# Image 59737 dimensions: (28, 28)
# Image 59738 dimensions: (28, 28)
# Image 59739 dimensions: (28, 28)
# Image 59740 dimensions: (28, 28)
# Image 59741 dimensions: (28, 28)
# Image 59742 dimensions: (28, 28)
# Image 59743 dimensions: (28, 28)
# Image 59744 dimensions: (28, 28)
# Image 59745 dimensions: (28, 28)
# Image 59746 dimensions: (28, 28)
# Image 59747 dimensions: (28, 28)
# Image 59748 dimensions: (28, 28)
# Image 59749 dimensions: (28, 28)
# Image 59750 dimensions: (28, 28)
# Image 59751 dimensions: (28, 28)
# Image 59752 dimensions: (28, 28)
# Image 59753 dimensions: (28, 28)
# Image 59754 dimensions: (28, 28)
# Image 59755 dimensions: (28, 28)
# Image 59756 dimensions: (28, 28)
# Image 59757 dimensions: (28, 28)
# Image 59758 dimensions: (28, 28)
# Image 59759 dimensions: (28, 28)
# Image 59760 dimensions: (28, 28)
# Image 59761 dimensions: (28, 28)
# Image 59762 dimensions: (28, 28)
# Image 59763 dimensions: (28, 28)
# Image 59764 dimensions: (28, 28)
# Image 59765 dimensions: (28, 28)
# Image 59766 dimensions: (28, 28)
# Image 59767 dimensions: (28, 28)
# Image 59768 dimensions: (28, 28)
# Image 59769 dimensions: (28, 28)
# Image 59770 dimensions: (28, 28)
# Image 59771 dimensions: (28, 28)
# Image 59772 dimensions: (28, 28)
# Image 59773 dimensions: (28, 28)
# Image 59774 dimensions: (28, 28)
# Image 59775 dimensions: (28, 28)
# Image 59776 dimensions: (28, 28)
# Image 59777 dimensions: (28, 28)
# Image 59778 dimensions: (28, 28)
# Image 59779 dimensions: (28, 28)
# Image 59780 dimensions: (28, 28)
# Image 59781 dimensions: (28, 28)
# Image 59782 dimensions: (28, 28)
# Image 59783 dimensions: (28, 28)
# Image 59784 dimensions: (28, 28)
# Image 59785 dimensions: (28, 28)
# Image 59786 dimensions: (28, 28)
# Image 59787 dimensions: (28, 28)
# Image 59788 dimensions: (28, 28)
# Image 59789 dimensions: (28, 28)
# Image 59790 dimensions: (28, 28)
# Image 59791 dimensions: (28, 28)
# Image 59792 dimensions: (28, 28)
# Image 59793 dimensions: (28, 28)
# Image 59794 dimensions: (28, 28)
# Image 59795 dimensions: (28, 28)
# Image 59796 dimensions: (28, 28)
# Image 59797 dimensions: (28, 28)
# Image 59798 dimensions: (28, 28)
# Image 59799 dimensions: (28, 28)
# Image 59800 dimensions: (28, 28)
# Image 59801 dimensions: (28, 28)
# Image 59802 dimensions: (28, 28)
# Image 59803 dimensions: (28, 28)
# Image 59804 dimensions: (28, 28)
# Image 59805 dimensions: (28, 28)
# Image 59806 dimensions: (28, 28)
# Image 59807 dimensions: (28, 28)
# Image 59808 dimensions: (28, 28)
# Image 59809 dimensions: (28, 28)
# Image 59810 dimensions: (28, 28)
# Image 59811 dimensions: (28, 28)
# Image 59812 dimensions: (28, 28)
# Image 59813 dimensions: (28, 28)
# Image 59814 dimensions: (28, 28)
# Image 59815 dimensions: (28, 28)
# Image 59816 dimensions: (28, 28)
# Image 59817 dimensions: (28, 28)
# Image 59818 dimensions: (28, 28)
# Image 59819 dimensions: (28, 28)
# Image 59820 dimensions: (28, 28)
# Image 59821 dimensions: (28, 28)
# Image 59822 dimensions: (28, 28)
# Image 59823 dimensions: (28, 28)
# Image 59824 dimensions: (28, 28)
# Image 59825 dimensions: (28, 28)
# Image 59826 dimensions: (28, 28)
# Image 59827 dimensions: (28, 28)
# Image 59828 dimensions: (28, 28)
# Image 59829 dimensions: (28, 28)
# Image 59830 dimensions: (28, 28)
# Image 59831 dimensions: (28, 28)
# Image 59832 dimensions: (28, 28)
# Image 59833 dimensions: (28, 28)
# Image 59834 dimensions: (28, 28)
# Image 59835 dimensions: (28, 28)
# Image 59836 dimensions: (28, 28)
# Image 59837 dimensions: (28, 28)
# Image 59838 dimensions: (28, 28)
# Image 59839 dimensions: (28, 28)
# Image 59840 dimensions: (28, 28)
# Image 59841 dimensions: (28, 28)
# Image 59842 dimensions: (28, 28)
# Image 59843 dimensions: (28, 28)
# Image 59844 dimensions: (28, 28)
# Image 59845 dimensions: (28, 28)
# Image 59846 dimensions: (28, 28)
# Image 59847 dimensions: (28, 28)
# Image 59848 dimensions: (28, 28)
# Image 59849 dimensions: (28, 28)
# Image 59850 dimensions: (28, 28)
# Image 59851 dimensions: (28, 28)
# Image 59852 dimensions: (28, 28)
# Image 59853 dimensions: (28, 28)
# Image 59854 dimensions: (28, 28)
# Image 59855 dimensions: (28, 28)
# Image 59856 dimensions: (28, 28)
# Image 59857 dimensions: (28, 28)
# Image 59858 dimensions: (28, 28)
# Image 59859 dimensions: (28, 28)
# Image 59860 dimensions: (28, 28)
# Image 59861 dimensions: (28, 28)
# Image 59862 dimensions: (28, 28)
# Image 59863 dimensions: (28, 28)
# Image 59864 dimensions: (28, 28)
# Image 59865 dimensions: (28, 28)
# Image 59866 dimensions: (28, 28)
# Image 59867 dimensions: (28, 28)
# Image 59868 dimensions: (28, 28)
# Image 59869 dimensions: (28, 28)
# Image 59870 dimensions: (28, 28)
# Image 59871 dimensions: (28, 28)
# Image 59872 dimensions: (28, 28)
# Image 59873 dimensions: (28, 28)
# Image 59874 dimensions: (28, 28)
# Image 59875 dimensions: (28, 28)
# Image 59876 dimensions: (28, 28)
# Image 59877 dimensions: (28, 28)
# Image 59878 dimensions: (28, 28)
# Image 59879 dimensions: (28, 28)
# Image 59880 dimensions: (28, 28)
# Image 59881 dimensions: (28, 28)
# Image 59882 dimensions: (28, 28)
# Image 59883 dimensions: (28, 28)
# Image 59884 dimensions: (28, 28)
# Image 59885 dimensions: (28, 28)
# Image 59886 dimensions: (28, 28)
# Image 59887 dimensions: (28, 28)
# Image 59888 dimensions: (28, 28)
# Image 59889 dimensions: (28, 28)
# Image 59890 dimensions: (28, 28)
# Image 59891 dimensions: (28, 28)
# Image 59892 dimensions: (28, 28)
# Image 59893 dimensions: (28, 28)
# Image 59894 dimensions: (28, 28)
# Image 59895 dimensions: (28, 28)
# Image 59896 dimensions: (28, 28)
# Image 59897 dimensions: (28, 28)
# Image 59898 dimensions: (28, 28)
# Image 59899 dimensions: (28, 28)
# Image 59900 dimensions: (28, 28)
# Image 59901 dimensions: (28, 28)
# Image 59902 dimensions: (28, 28)
# Image 59903 dimensions: (28, 28)
# Image 59904 dimensions: (28, 28)
# Image 59905 dimensions: (28, 28)
# Image 59906 dimensions: (28, 28)
# Image 59907 dimensions: (28, 28)
# Image 59908 dimensions: (28, 28)
# Image 59909 dimensions: (28, 28)
# Image 59910 dimensions: (28, 28)
# Image 59911 dimensions: (28, 28)
# Image 59912 dimensions: (28, 28)
# Image 59913 dimensions: (28, 28)
# Image 59914 dimensions: (28, 28)
# Image 59915 dimensions: (28, 28)
# Image 59916 dimensions: (28, 28)
# Image 59917 dimensions: (28, 28)
# Image 59918 dimensions: (28, 28)
# Image 59919 dimensions: (28, 28)
# Image 59920 dimensions: (28, 28)
# Image 59921 dimensions: (28, 28)
# Image 59922 dimensions: (28, 28)
# Image 59923 dimensions: (28, 28)
# Image 59924 dimensions: (28, 28)
# Image 59925 dimensions: (28, 28)
# Image 59926 dimensions: (28, 28)
# Image 59927 dimensions: (28, 28)
# Image 59928 dimensions: (28, 28)
# Image 59929 dimensions: (28, 28)
# Image 59930 dimensions: (28, 28)
# Image 59931 dimensions: (28, 28)
# Image 59932 dimensions: (28, 28)
# Image 59933 dimensions: (28, 28)
# Image 59934 dimensions: (28, 28)
# Image 59935 dimensions: (28, 28)
# Image 59936 dimensions: (28, 28)
# Image 59937 dimensions: (28, 28)
# Image 59938 dimensions: (28, 28)
# Image 59939 dimensions: (28, 28)
# Image 59940 dimensions: (28, 28)
# Image 59941 dimensions: (28, 28)
# Image 59942 dimensions: (28, 28)
# Image 59943 dimensions: (28, 28)
# Image 59944 dimensions: (28, 28)
# Image 59945 dimensions: (28, 28)
# Image 59946 dimensions: (28, 28)
# Image 59947 dimensions: (28, 28)
# Image 59948 dimensions: (28, 28)
# Image 59949 dimensions: (28, 28)
# Image 59950 dimensions: (28, 28)
# Image 59951 dimensions: (28, 28)
# Image 59952 dimensions: (28, 28)
# Image 59953 dimensions: (28, 28)
# Image 59954 dimensions: (28, 28)
# Image 59955 dimensions: (28, 28)
# Image 59956 dimensions: (28, 28)
# Image 59957 dimensions: (28, 28)
# Image 59958 dimensions: (28, 28)
# Image 59959 dimensions: (28, 28)
# Image 59960 dimensions: (28, 28)
# Image 59961 dimensions: (28, 28)
# Image 59962 dimensions: (28, 28)
# Image 59963 dimensions: (28, 28)
# Image 59964 dimensions: (28, 28)
# Image 59965 dimensions: (28, 28)
# Image 59966 dimensions: (28, 28)
# Image 59967 dimensions: (28, 28)
# Image 59968 dimensions: (28, 28)
# Image 59969 dimensions: (28, 28)
# Image 59970 dimensions: (28, 28)
# Image 59971 dimensions: (28, 28)
# Image 59972 dimensions: (28, 28)
# Image 59973 dimensions: (28, 28)
# Image 59974 dimensions: (28, 28)
# Image 59975 dimensions: (28, 28)
# Image 59976 dimensions: (28, 28)
# Image 59977 dimensions: (28, 28)
# Image 59978 dimensions: (28, 28)
# Image 59979 dimensions: (28, 28)
# Image 59980 dimensions: (28, 28)
# Image 59981 dimensions: (28, 28)
# Image 59982 dimensions: (28, 28)
# Image 59983 dimensions: (28, 28)
# Image 59984 dimensions: (28, 28)
# Image 59985 dimensions: (28, 28)
# Image 59986 dimensions: (28, 28)
# Image 59987 dimensions: (28, 28)
# Image 59988 dimensions: (28, 28)
# Image 59989 dimensions: (28, 28)
# Image 59990 dimensions: (28, 28)
# Image 59991 dimensions: (28, 28)
# Image 59992 dimensions: (28, 28)
# Image 59993 dimensions: (28, 28)
# Image 59994 dimensions: (28, 28)
# Image 59995 dimensions: (28, 28)
# Image 59996 dimensions: (28, 28)
# Image 59997 dimensions: (28, 28)
# Image 59998 dimensions: (28, 28)
# Image 59999 dimensions: (28, 28)
# Image 60000 dimensions: (28, 28)

# %% [markdown]
# #### Preprocessing

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Preprocess the data

# Normalize pixel values to a range between 0 and 1
x_train = x_train.astype('float32')
x_train /= 255
x_test = x_test.astype('float32')
x_test /= 255

# Convert labels to one-hot encoded vectors
y_train =to_categorical(y_train)
# y_test = to_categorical(y_test)
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# Print the shapes of the preprocessed data
print("Preprocessed Data Shapes:")
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# Preprocessed Data Shapes:
# x_train shape: (60000, 28, 28)
# y_train shape: (60000, 10, 2)
# x_test shape: (10000, 28, 28)
# y_test shape: (10000, 10)

# %% [markdown]
# ## Q2) Performing experiments on Fully Connected Neural Networks (FCNN):

# %% [markdown]
# #### Step 1: Designing the FCNN Architecture

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

# Create a Sequential model
FCNN = Sequential()

# Flatten the input images
FCNN.add(Flatten(input_shape=(28, 28)))

# Add fully connected layers
FCNN.add(Dense(1000, activation='relu'))
FCNN.add(Dense(100, activation='relu'))
FCNN.add(Dense(10, activation='softmax'))

# Compile the model
FCNN.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Display model summary
FCNN.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_13 (Flatten)        (None, 784)               0
#
#  dense_32 (Dense)            (None, 1000)              785000
#
#  dense_33 (Dense)            (None, 100)               100100
#
#  dense_34 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 886,110
# Trainable params: 886,110
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Step 2: Training and Testing the Network

# %%
# Train the model
epochs = 10  # Experimenting with different random values

history1 = FCNN.fit(x_train, y_train,
                    epochs=epochs,
                    verbose=1)
FCNN.save('FCNN.h5')
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4692 - accuracy: 0.8301
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3583 - accuracy: 0.8688
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3195 - accuracy: 0.8820
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2926 - accuracy: 0.8910
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2765 - accuracy: 0.8972
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2618 - accuracy: 0.9009
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2503 - accuracy: 0.9060
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2406 - accuracy: 0.9090
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2315 - accuracy: 0.9120
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2195 - accuracy: 0.9167

# %% [markdown]
# #### Step 3: Plotting Performance Curves

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history1.history['accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history1.history['loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train'], loc='upper left')
plt.show()

# %% [markdown]
# ## Q3) Performing experiments on a Convolutional Neural Networks (CNNs):

# %% [markdown]
# ### a. Design CNN-1 which contains:
# ### • One Convolution layer which uses 32 kernels each of size 5x5, stride = 1 and, padding =0.
# ### • One Pooling layer which uses MAXPOOLING with stride =2.
# ### • One hidden layer having number of neurons = 100

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

# Create CNN-1 architecture
CNN1 = Sequential([
    Conv2D(32, (5, 5), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2), strides=2),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
CNN1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
CNN1.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 24, 24, 32)        832
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_14 (Flatten)        (None, 4608)              0
#
#  dense_35 (Dense)            (None, 100)               460900
#
#  dense_36 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 462,742
# Trainable params: 462,742
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = CNN1.fit(x_train, y_train,
                    epochs=10,
                    validation_split=0.25,
                    verbose=1)
CNN1.save('CNN1.h5')
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4433 - accuracy: 0.8446 - val_loss: 0.3332 - val_accuracy: 0.8803
# Epoch 2/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.3030 - accuracy: 0.8914 - val_loss: 0.2995 - val_accuracy: 0.8955
# Epoch 3/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.2567 - accuracy: 0.9063 - val_loss: 0.3065 - val_accuracy: 0.8862
# Epoch 4/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.2231 - accuracy: 0.9188 - val_loss: 0.2642 - val_accuracy: 0.9067
# Epoch 5/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.1927 - accuracy: 0.9284 - val_loss: 0.2558 - val_accuracy: 0.9109
# Epoch 6/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.1708 - accuracy: 0.9356 - val_loss: 0.2817 - val_accuracy: 0.9021
# Epoch 7/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.1494 - accuracy: 0.9434 - val_loss: 0.2881 - val_accuracy: 0.9039
# Epoch 8/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.1314 - accuracy: 0.9523 - val_loss: 0.2699 - val_accuracy: 0.9115
# Epoch 9/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.1157 - accuracy: 0.9570 - val_loss: 0.2769 - val_accuracy: 0.9110
# Epoch 10/10
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.1011 - accuracy: 0.9624 - val_loss: 0.3031 - val_accuracy: 0.9087

# %% [markdown]
# ### b. Design CNN-2 which contains:
# ### • Two back-to-back Convolution layers which uses 32 kernels each of size 3x3, stride = 1, and padding =0.
# ### • One Pooling layer which uses MAXPOOLING with stride =2.
# ### • One hidden layer having number of neurons = 100

# %%
# Create the Sequential model
CNN2 = Sequential()

# Convolutional Layer 1
CNN2.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# Convolutional Layer 2
CNN2.add(Conv2D(32, (3, 3), activation='relu'))
# MaxPooling Layer
CNN2.add(MaxPooling2D(pool_size=(2, 2), strides=2))
# Flatten Layer
CNN2.add(Flatten())
# Hidden Layer
CNN2.add(Dense(100, activation='relu'))
# Output Layer (modify units and activation based on your task)
CNN2.add(Dense(num_classes, activation='softmax'))

# Compile the model
CNN2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
CNN2.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 26, 26, 32)        320
#
#  conv2d_13 (Conv2D)          (None, 24, 24, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_15 (Flatten)        (None, 4608)              0
#
#  dense_37 (Dense)            (None, 100)               460900
#
#  dense_38 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 471,478
# Trainable params: 471,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
history3 = CNN2.fit(x_train, y_train,
                    epochs=10,
                    validation_split=0.25,
                    verbose=1)
CNN2.save('CNN2.h5')
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4167 - accuracy: 0.8527 - val_loss: 0.3105 - val_accuracy: 0.8855
# Epoch 2/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2624 - accuracy: 0.9040 - val_loss: 0.2526 - val_accuracy: 0.9073
# Epoch 3/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2121 - accuracy: 0.9214 - val_loss: 0.2395 - val_accuracy: 0.9137
# Epoch 4/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1695 - accuracy: 0.9383 - val_loss: 0.2391 - val_accuracy: 0.9143
# Epoch 5/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1337 - accuracy: 0.9503 - val_loss: 0.2472 - val_accuracy: 0.9193
# Epoch 6/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1039 - accuracy: 0.9623 - val_loss: 0.2613 - val_accuracy: 0.9157
# Epoch 7/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.0831 - accuracy: 0.9689 - val_loss: 0.2846 - val_accuracy: 0.9167
# Epoch 8/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.0629 - accuracy: 0.9765 - val_loss: 0.3181 - val_accuracy: 0.9163
# Epoch 9/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.0492 - accuracy: 0.9812 - val_loss: 0.3288 - val_accuracy: 0.9191
# Epoch 10/10
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.0396 - accuracy: 0.9856 - val_loss: 0.3792 - val_accuracy: 0.9192

# %%
import tensorflow as tf

# Load saved models
cnn_model1 = tf.keras.models.load_model('CNN1.h5') 
cnn_model2 = tf.keras.models.load_model('CNN2.h5')
fcnn_model = tf.keras.models.load_model('FCNN.h5')

# Print model summaries to compare the number of parameters
print("CNN-1 Model Summary:")
cnn_model1.summary()

print("\nCNN-2 Model Summary:")
cnn_model2.summary()

print("\nFCNN Model Summary:")
fcnn_model.summary()
# Out:
# CNN-1 Model Summary:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 24, 24, 32)        832
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_14 (Flatten)        (None, 4608)              0
#
#  dense_35 (Dense)            (None, 100)               460900
#
#  dense_36 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 462,742
# Trainable params: 462,742
# Non-trainable params: 0
# _________________________________________________________________
#
# CNN-2 Model Summary:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 26, 26, 32)        320
#
#  conv2d_13 (Conv2D)          (None, 24, 24, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_15 (Flatten)        (None, 4608)              0
#
#  dense_37 (Dense)            (None, 100)               460900
#
#  dense_38 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 471,478
# Trainable params: 471,478
# Non-trainable params: 0
# _________________________________________________________________
#
# FCNN Model Summary:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_13 (Flatten)        (None, 784)               0
#
#  dense_32 (Dense)            (None, 1000)              785000
#
#  dense_33 (Dense)            (None, 100)               100100
#
#  dense_34 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 886,110
# Trainable params: 886,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_plot(df):
    plt.plot(df.index,df['loss'],color = 'r',label = 'Loss')
    plt.plot(df.index,df['val_loss'],color = 'b',label = 'Validation Loss')
    plt.legend()
    plt.xlabel("EPochs")
    plt.ylabel("Loss")
    plt.show()

# %%
hist2 = pd.DataFrame(history2.history)
hist3 = pd.DataFrame(history3.history)
hist2
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.443325  0.844600  0.333159      0.880267
# 1  0.302959  0.891378  0.299529      0.895467
# 2  0.256653  0.906333  0.306451      0.886200
# 3  0.223058  0.918822  0.264164      0.906667
# 4  0.192733  0.928356  0.255822      0.910933
# 5  0.170841  0.935578  0.281730      0.902133
# 6  0.149354  0.943400  0.288136      0.903867
# 7  0.131403  0.952267  0.269862      0.911467
# 8  0.115698  0.956978  0.276934      0.911000
# 9  0.101111  0.962356  0.303148      0.908733

# %%
hist3
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.416698  0.852733  0.310459      0.885533
# 1  0.262411  0.904044  0.252638      0.907267
# 2  0.212138  0.921400  0.239476      0.913733
# 3  0.169522  0.938289  0.239147      0.914333
# 4  0.133682  0.950311  0.247206      0.919267
# 5  0.103877  0.962311  0.261306      0.915667
# 6  0.083094  0.968911  0.284631      0.916667
# 7  0.062920  0.976467  0.318147      0.916267
# 8  0.049237  0.981156  0.328816      0.919067
# 9  0.039579  0.985644  0.379248      0.919200

# %%
loss_plot(hist2)
loss_plot(hist3)

# %% [markdown]
# #### The two preceding graphs depict the loss trends over various epochs for two convolutional neural networks (convnet 1 and convnet 2). In the case of the second model, the validation loss starts to rise after a certain point, which suggests that the model is beginning to overfit the training data. Conversely, the second model, represented in the first graph, demonstrates consistent behavior as its validation loss remains relatively stable throughout, indicating a lack of overfitting to the training data.
