# %% [markdown]
# ## Importing Necessary Libraries

# %%
# Preprocessing and Visualizing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

# Neural Network
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv("bodyfat.csv")

# %% [markdown]
# #### Taking a glance at the data

# %%
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %% [markdown]
# #### Checking For missing values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Finding the number of Rows and Columns

# %%
df.shape
# Out:
# (252, 15)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='BodyFat', bins=20, kde=True)

plt.title('Histogram of BodyFat - Data is normally distributed')
plt.xlabel('BodyFat')
plt.show()

# %%
sns.pairplot(df[['Weight', 'Height', 'Abdomen', 'Thigh']])
plt.show()

# %%
# Correlation heatmap

corr_matrix = df.corr()
plt.figure(figsize=(12, 7))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap - Correlation between different features')
plt.show()

# %% [markdown]
# #### BodyFat is highly correlated to Density, Chest circumference, Abdomen circumference & Weight, Hips circumference and Thighs circumference to some extent

# %% [markdown]
# ## Splitting the dataset (80/20 split)

# %%
y = df['BodyFat']
X = df.drop('BodyFat', axis =1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %% [markdown]
# #### Standardzing the data

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# ## Deep Learning Model

# %% [markdown]
# #### Making a sequential model with 3 hidden layers and 1 output layer

# %%
model = Sequential()

model.add(Dense(128, activation = 'relu', input_shape = (X_train_scaled.shape[1],)))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
# model.add(Dense(16, activation = 'relu'))
model.add(Dense(1))

# %% [markdown]
# #### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               1920
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  dense_12 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 12289 (48.00 KB)
# Trainable params: 12289 (48.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Defining Learning Rate and Compiling the Model with Adam optimizer

# %%
learning_rate = 0.1
model.compile(optimizer = tf.keras.optimizers.legacy.Adam(learning_rate = learning_rate),
              loss='mse',
              metrics=tf.keras.metrics.RootMeanSquaredError())

# %% [markdown]
# #### Running the model for 100 epochs and fitting it onto our data

# %%
epochs = 100
batch_size = 10
model.fit(X_train_scaled, y_train, epochs=epochs, batch_size = batch_size, validation_split = 0.1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 5ms/step - loss: 358.9424 - root_mean_squared_error: 18.9458 - val_loss: 217.2374 - val_root_mean_squared_error: 14.7390
# Epoch 2/100
# 18/18 [==============================] - 0s 1ms/step - loss: 170.4772 - root_mean_squared_error: 13.0567 - val_loss: 49.1214 - val_root_mean_squared_error: 7.0087
# Epoch 3/100
# 18/18 [==============================] - 0s 1ms/step - loss: 57.5406 - root_mean_squared_error: 7.5856 - val_loss: 56.8735 - val_root_mean_squared_error: 7.5415
# Epoch 4/100
# 18/18 [==============================] - 0s 1ms/step - loss: 17.6007 - root_mean_squared_error: 4.1953 - val_loss: 8.1320 - val_root_mean_squared_error: 2.8517
# Epoch 5/100
# 18/18 [==============================] - 0s 1ms/step - loss: 18.0910 - root_mean_squared_error: 4.2533 - val_loss: 6.7034 - val_root_mean_squared_error: 2.5891
# Epoch 6/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.1746 - root_mean_squared_error: 2.2748 - val_loss: 5.5480 - val_root_mean_squared_error: 2.3554
# Epoch 7/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.5825 - root_mean_squared_error: 1.8928 - val_loss: 4.4048 - val_root_mean_squared_error: 2.0988
# Epoch 8/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.7273 - root_mean_squared_error: 1.6515 - val_loss: 3.1422 - val_root_mean_squared_error: 1.7726
# Epoch 9/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.9580 - root_mean_squared_error: 1.3993 - val_loss: 2.5999 - val_root_mean_squared_error: 1.6124
# Epoch 10/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.1000 - root_mean_squared_error: 1.4491 - val_loss: 4.0519 - val_root_mean_squared_error: 2.0129
# Epoch 11/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.3603 - root_mean_squared_error: 1.5363 - val_loss: 2.4523 - val_root_mean_squared_error: 1.5660
# Epoch 12/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.9726 - root_mean_squared_error: 1.7241 - val_loss: 4.7387 - val_root_mean_squared_error: 2.1769
# Epoch 13/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.1341 - root_mean_squared_error: 1.7703 - val_loss: 2.1876 - val_root_mean_squared_error: 1.4791
# Epoch 14/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.9688 - root_mean_squared_error: 1.9922 - val_loss: 4.8852 - val_root_mean_squared_error: 2.2103
# Epoch 15/100
# 18/18 [==============================] - 0s 1ms/step - loss: 4.8097 - root_mean_squared_error: 2.1931 - val_loss: 4.9657 - val_root_mean_squared_error: 2.2284
# Epoch 16/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.9512 - root_mean_squared_error: 2.4395 - val_loss: 2.8368 - val_root_mean_squared_error: 1.6843
# Epoch 17/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.9183 - root_mean_squared_error: 1.7083 - val_loss: 2.7629 - val_root_mean_squared_error: 1.6622
# Epoch 18/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3369 - root_mean_squared_error: 1.1563 - val_loss: 1.7286 - val_root_mean_squared_error: 1.3148
# Epoch 19/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.1273 - root_mean_squared_error: 1.0617 - val_loss: 2.1921 - val_root_mean_squared_error: 1.4806
# Epoch 20/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3785 - root_mean_squared_error: 1.1741 - val_loss: 1.6779 - val_root_mean_squared_error: 1.2953
# Epoch 21/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.0107 - root_mean_squared_error: 1.0053 - val_loss: 1.9186 - val_root_mean_squared_error: 1.3851
# Epoch 22/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8880 - root_mean_squared_error: 0.9423 - val_loss: 1.8969 - val_root_mean_squared_error: 1.3773
# Epoch 23/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.0423 - root_mean_squared_error: 1.0209 - val_loss: 3.2353 - val_root_mean_squared_error: 1.7987
# Epoch 24/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.7202 - root_mean_squared_error: 1.3116 - val_loss: 2.9755 - val_root_mean_squared_error: 1.7250
# Epoch 25/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.5580 - root_mean_squared_error: 1.2482 - val_loss: 5.3430 - val_root_mean_squared_error: 2.3115
# Epoch 26/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.1424 - root_mean_squared_error: 1.7727 - val_loss: 3.3757 - val_root_mean_squared_error: 1.8373
# Epoch 27/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.4443 - root_mean_squared_error: 1.5634 - val_loss: 3.4929 - val_root_mean_squared_error: 1.8689
# Epoch 28/100
# 18/18 [==============================] - 0s 1ms/step - loss: 4.5757 - root_mean_squared_error: 2.1391 - val_loss: 2.5974 - val_root_mean_squared_error: 1.6117
# Epoch 29/100
# 18/18 [==============================] - 0s 1ms/step - loss: 4.2180 - root_mean_squared_error: 2.0538 - val_loss: 3.6540 - val_root_mean_squared_error: 1.9115
# Epoch 30/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.5489 - root_mean_squared_error: 1.8838 - val_loss: 3.3996 - val_root_mean_squared_error: 1.8438
# Epoch 31/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.9355 - root_mean_squared_error: 1.3912 - val_loss: 1.9767 - val_root_mean_squared_error: 1.4060
# Epoch 32/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.6076 - root_mean_squared_error: 1.8994 - val_loss: 2.5521 - val_root_mean_squared_error: 1.5975
# Epoch 33/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.4015 - root_mean_squared_error: 1.8443 - val_loss: 5.1320 - val_root_mean_squared_error: 2.2654
# Epoch 34/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.6726 - root_mean_squared_error: 2.3817 - val_loss: 8.4077 - val_root_mean_squared_error: 2.8996
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 10.5023 - root_mean_squared_error: 3.2407 - val_loss: 4.5404 - val_root_mean_squared_error: 2.1308
# Epoch 36/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.8446 - root_mean_squared_error: 1.6866 - val_loss: 4.0139 - val_root_mean_squared_error: 2.0035
# Epoch 37/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.1604 - root_mean_squared_error: 1.7778 - val_loss: 4.6800 - val_root_mean_squared_error: 2.1633
# Epoch 38/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.4855 - root_mean_squared_error: 1.8670 - val_loss: 4.0411 - val_root_mean_squared_error: 2.0102
# Epoch 39/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.7257 - root_mean_squared_error: 1.6510 - val_loss: 6.3592 - val_root_mean_squared_error: 2.5218
# Epoch 40/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.5790 - root_mean_squared_error: 1.8918 - val_loss: 4.4093 - val_root_mean_squared_error: 2.0998
# Epoch 41/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.7138 - root_mean_squared_error: 1.3091 - val_loss: 2.5852 - val_root_mean_squared_error: 1.6079
# Epoch 42/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3912 - root_mean_squared_error: 1.1795 - val_loss: 4.8622 - val_root_mean_squared_error: 2.2050
# Epoch 43/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3982 - root_mean_squared_error: 1.1824 - val_loss: 3.3624 - val_root_mean_squared_error: 1.8337
# Epoch 44/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2336 - root_mean_squared_error: 1.1107 - val_loss: 2.7301 - val_root_mean_squared_error: 1.6523
# Epoch 45/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8973 - root_mean_squared_error: 0.9472 - val_loss: 2.2739 - val_root_mean_squared_error: 1.5080
# Epoch 46/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.3887 - root_mean_squared_error: 1.5455 - val_loss: 14.7205 - val_root_mean_squared_error: 3.8367
# Epoch 47/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.4740 - root_mean_squared_error: 1.8639 - val_loss: 3.1017 - val_root_mean_squared_error: 1.7612
# Epoch 48/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.2533 - root_mean_squared_error: 1.8037 - val_loss: 2.4387 - val_root_mean_squared_error: 1.5616
# Epoch 49/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.9771 - root_mean_squared_error: 1.4061 - val_loss: 3.3659 - val_root_mean_squared_error: 1.8346
# Epoch 50/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2220 - root_mean_squared_error: 1.1054 - val_loss: 2.4571 - val_root_mean_squared_error: 1.5675
# Epoch 51/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.1971 - root_mean_squared_error: 1.0941 - val_loss: 2.5921 - val_root_mean_squared_error: 1.6100
# Epoch 52/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7518 - root_mean_squared_error: 0.8671 - val_loss: 2.7965 - val_root_mean_squared_error: 1.6723
# Epoch 53/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7921 - root_mean_squared_error: 0.8900 - val_loss: 3.4982 - val_root_mean_squared_error: 1.8704
# Epoch 54/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.1311 - root_mean_squared_error: 1.0636 - val_loss: 5.2350 - val_root_mean_squared_error: 2.2880
# Epoch 55/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.6526 - root_mean_squared_error: 1.2855 - val_loss: 4.0393 - val_root_mean_squared_error: 2.0098
# Epoch 56/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8896 - root_mean_squared_error: 0.9432 - val_loss: 3.9403 - val_root_mean_squared_error: 1.9850
# Epoch 57/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8083 - root_mean_squared_error: 0.8990 - val_loss: 4.1980 - val_root_mean_squared_error: 2.0489
# Epoch 58/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7966 - root_mean_squared_error: 0.8925 - val_loss: 4.0253 - val_root_mean_squared_error: 2.0063
# Epoch 59/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.5638 - root_mean_squared_error: 1.2505 - val_loss: 6.7739 - val_root_mean_squared_error: 2.6027
# Epoch 60/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.9332 - root_mean_squared_error: 2.4358 - val_loss: 8.2916 - val_root_mean_squared_error: 2.8795
# Epoch 61/100
# 18/18 [==============================] - 0s 1ms/step - loss: 6.7470 - root_mean_squared_error: 2.5975 - val_loss: 4.8539 - val_root_mean_squared_error: 2.2032
# Epoch 62/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.9992 - root_mean_squared_error: 2.4493 - val_loss: 16.6596 - val_root_mean_squared_error: 4.0816
# Epoch 63/100
# 18/18 [==============================] - 0s 1ms/step - loss: 9.5827 - root_mean_squared_error: 3.0956 - val_loss: 5.0060 - val_root_mean_squared_error: 2.2374
# Epoch 64/100
# 18/18 [==============================] - 0s 1ms/step - loss: 3.7294 - root_mean_squared_error: 1.9312 - val_loss: 7.3052 - val_root_mean_squared_error: 2.7028
# Epoch 65/100
# 18/18 [==============================] - 0s 1ms/step - loss: 5.7455 - root_mean_squared_error: 2.3970 - val_loss: 11.1103 - val_root_mean_squared_error: 3.3332
# Epoch 66/100
# 18/18 [==============================] - 0s 1ms/step - loss: 4.4323 - root_mean_squared_error: 2.1053 - val_loss: 3.1463 - val_root_mean_squared_error: 1.7738
# Epoch 67/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.5518 - root_mean_squared_error: 1.2457 - val_loss: 3.1647 - val_root_mean_squared_error: 1.7790
# Epoch 68/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.0537 - root_mean_squared_error: 1.4331 - val_loss: 2.7700 - val_root_mean_squared_error: 1.6643
# Epoch 69/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3429 - root_mean_squared_error: 1.1588 - val_loss: 2.1376 - val_root_mean_squared_error: 1.4621
# Epoch 70/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2637 - root_mean_squared_error: 1.1242 - val_loss: 3.2512 - val_root_mean_squared_error: 1.8031
# Epoch 71/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.8633 - root_mean_squared_error: 1.3650 - val_loss: 2.9160 - val_root_mean_squared_error: 1.7076
# Epoch 72/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3536 - root_mean_squared_error: 1.1634 - val_loss: 2.1921 - val_root_mean_squared_error: 1.4806
# Epoch 73/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7847 - root_mean_squared_error: 0.8858 - val_loss: 2.2086 - val_root_mean_squared_error: 1.4861
# Epoch 74/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.1203 - root_mean_squared_error: 1.0584 - val_loss: 2.9160 - val_root_mean_squared_error: 1.7076
# Epoch 75/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8951 - root_mean_squared_error: 0.9461 - val_loss: 1.8769 - val_root_mean_squared_error: 1.3700
# Epoch 76/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6188 - root_mean_squared_error: 0.7866 - val_loss: 2.0966 - val_root_mean_squared_error: 1.4480
# Epoch 77/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6740 - root_mean_squared_error: 0.8209 - val_loss: 2.1432 - val_root_mean_squared_error: 1.4640
# Epoch 78/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8167 - root_mean_squared_error: 0.9037 - val_loss: 2.7119 - val_root_mean_squared_error: 1.6468
# Epoch 79/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3299 - root_mean_squared_error: 1.1532 - val_loss: 3.2744 - val_root_mean_squared_error: 1.8095
# Epoch 80/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.5254 - root_mean_squared_error: 1.2351 - val_loss: 2.0694 - val_root_mean_squared_error: 1.4385
# Epoch 81/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.0342 - root_mean_squared_error: 1.0169 - val_loss: 2.8934 - val_root_mean_squared_error: 1.7010
# Epoch 82/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.4153 - root_mean_squared_error: 1.1897 - val_loss: 2.2574 - val_root_mean_squared_error: 1.5025
# Epoch 83/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.1823 - root_mean_squared_error: 1.0873 - val_loss: 2.3005 - val_root_mean_squared_error: 1.5167
# Epoch 84/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7690 - root_mean_squared_error: 0.8769 - val_loss: 3.6426 - val_root_mean_squared_error: 1.9086
# Epoch 85/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8734 - root_mean_squared_error: 0.9345 - val_loss: 2.5204 - val_root_mean_squared_error: 1.5876
# Epoch 86/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8623 - root_mean_squared_error: 0.9286 - val_loss: 2.3953 - val_root_mean_squared_error: 1.5477
# Epoch 87/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3652 - root_mean_squared_error: 1.1684 - val_loss: 3.4033 - val_root_mean_squared_error: 1.8448
# Epoch 88/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.4887 - root_mean_squared_error: 1.5776 - val_loss: 11.3367 - val_root_mean_squared_error: 3.3670
# Epoch 89/100
# 18/18 [==============================] - 0s 1ms/step - loss: 2.5018 - root_mean_squared_error: 1.5817 - val_loss: 4.6023 - val_root_mean_squared_error: 2.1453
# Epoch 90/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.9638 - root_mean_squared_error: 0.9817 - val_loss: 2.2683 - val_root_mean_squared_error: 1.5061
# Epoch 91/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.0245 - root_mean_squared_error: 1.0122 - val_loss: 4.1412 - val_root_mean_squared_error: 2.0350
# Epoch 92/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.5660 - root_mean_squared_error: 1.2514 - val_loss: 1.8909 - val_root_mean_squared_error: 1.3751
# Epoch 93/100
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3364 - root_mean_squared_error: 1.1560 - val_loss: 2.9828 - val_root_mean_squared_error: 1.7271
# Epoch 94/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8731 - root_mean_squared_error: 0.9344 - val_loss: 1.8921 - val_root_mean_squared_error: 1.3755
# Epoch 95/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6046 - root_mean_squared_error: 0.7775 - val_loss: 2.8131 - val_root_mean_squared_error: 1.6772
# Epoch 96/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8982 - root_mean_squared_error: 0.9477 - val_loss: 2.9956 - val_root_mean_squared_error: 1.7308
# Epoch 97/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5694 - root_mean_squared_error: 0.7546 - val_loss: 1.9238 - val_root_mean_squared_error: 1.3870
# Epoch 98/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4999 - root_mean_squared_error: 0.7071 - val_loss: 2.2754 - val_root_mean_squared_error: 1.5084
# Epoch 99/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5109 - root_mean_squared_error: 0.7148 - val_loss: 1.9351 - val_root_mean_squared_error: 1.3911
# Epoch 100/100
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7985 - root_mean_squared_error: 0.8936 - val_loss: 2.9984 - val_root_mean_squared_error: 1.7316

# %%
loss, accuracy = model.evaluate(X_test_scaled, y_test, batch_size=batch_size)
print("RMSE:", loss)
# Out:
# 6/6 [==============================] - 0s 780us/step - loss: 8.2432 - root_mean_squared_error: 2.8711
# RMSE: 8.243156433105469
