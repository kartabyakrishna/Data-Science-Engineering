# %%
from tensorflow.keras.applications import LeNet5

model_lenet = LeNet5(weights=None, input_shape=(32, 32, 3), classes=2)  # 'classes' should match your problem's number of classes
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-6187e92a836e> in <cell line: 1>()
# ----> 1 from tensorflow.keras.applications import LeNet5
#       2
#       3 model_lenet = LeNet5(weights=None, input_shape=(32, 32, 3), classes=2)  # 'classes' should match your problem's number of classes
#
# ImportError: cannot import name 'LeNet5' from 'tensorflow.keras.applications' (/usr/local/lib/python3.10/dist-packages/keras/api/_v2/keras/applications/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
